# %%
import datetime
import time
import pymupdf as fitz  # PyMuPDF
import requests
import json
import numpy as np
from transformers import BertTokenizer
import os

# %% [markdown]
# # 文本分割函数

# %%
# 初始化BERT tokenizer
tokenizer = BertTokenizer.from_pretrained("bert-base-uncased")

def split_text(text, max_length, max_tokens):
    """将文本按字符数和token数分割成不超过max_length字符和max_tokens的段落"""
    paragraphs = []
    current_paragraph = ""
    current_tokens = 0

    for line in text.split("\n"):
        line_tokens = tokenizer.encode(line, add_special_tokens=False)
        if (len(current_paragraph) + len(line) + 1 <= max_length) and (current_tokens + len(line_tokens) + 1 <= max_tokens):
            current_paragraph += line + "\n"
            current_tokens += len(line_tokens) + 1  # +1 for the newline token
        else:
            paragraphs.append(current_paragraph.strip())
            current_paragraph = line + "\n"
            current_tokens = len(line_tokens) + 1

    if current_paragraph:
        paragraphs.append(current_paragraph.strip())
    return paragraphs
# Out:
# /root/miniconda3/envs/dev/lib/python3.10/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(

# %% [markdown]
# # 从PDF中提取文本

# %%
import os

# 从PDF文件中提取文本函数
def extract_text_from_pdf(pdf_path):
    text = ""
    pdf_document = fitz.open(pdf_path)
    for page_num in range(len(pdf_document)):
        page = pdf_document.load_page(page_num)
        text += page.get_text()
    return text


# 提取PDF文件中的文本并按token数和字符数分割
pdf_files = ["20240401-0级.pdf"]
max_length = 18000
max_tokens = 4000
documents = []
for pdf in pdf_files:
    text = extract_text_from_pdf(pdf)
    paragraphs = split_text(text, max_length, max_tokens)
    documents.extend(paragraphs)

# 将分割后的文本块分别存储到多个txt文件中，并保存文件名到一个列表中
txt_dir = 'new_txt_files'
file_names = []
for idx, doc in enumerate(documents, start=1):
    file_name = os.path.join(txt_dir, f"text_file{idx}.txt")
    with open(file_name, "w", encoding="utf-8") as file:
        file.write(doc)
    file_names.append(file_name)

print("文本文件已成功生成。")
print("生成的文件名列表：", file_names)
# Out:
# 文本文件已成功生成。
# 生成的文件名列表： ['new_txt_files/text_file1.txt', 'new_txt_files/text_file2.txt', 'new_txt_files/text_file3.txt', 'new_txt_files/text_file4.txt', 'new_txt_files/text_file5.txt', 'new_txt_files/text_file6.txt', 'new_txt_files/text_file7.txt', 'new_txt_files/text_file8.txt', 'new_txt_files/text_file9.txt', 'new_txt_files/text_file10.txt', 'new_txt_files/text_file11.txt', 'new_txt_files/text_file12.txt', 'new_txt_files/text_file13.txt']

# %% [markdown]
# # 问题生成prompt

# %%
prompt1 = '''
#01 你是一个问答对数据集处理专家。

#02 你的任务是根据我给出的内容，生成适合作为问答对数据集的问题。

#03 该内容有很多从表格中提取出的内容，多根据表格内容生成问题。

#04 问题要尽量短，不要太长。

#05 一句话中只能有一个问题，问题尽量有意义。

#06 最多生成10个问题。

#07 生成问题示例：

"""

"积分视场光谱仪的0级数据包含哪些内容？"
"MCI模块的数据文件命名规范是什么样的？"
"MSC_MS 0级数据关键字PCOUNT是什么意思？"
"MSC_MS 0级数据关键字EXTVER的数据类型是什么？"

"""

#07 以下是我给出的内容：

"""

{{此处替换成你的内容}}

"""
'''

# %% [markdown]
# # 问答对生成prompt

# %%
prompt2 = '''
#01 你是一个问答对数据集处理专家。

#02 你的任务是根据我的问题和我给出的内容，生成对应的问答对。

#03 答案要全面，只使用我的信息，如果找不到答案，就回复从文档中找不到答案。

#04 你必须根据我的问答对示例格式来生成：

"""

{"content": "积分视场光谱仪的0级数据包含哪些内容？", "summary": "积分视场光谱仪包含以下内容：1.观测目标的原始曝光图像；2.参考图像， 包括偏置、 平场、 暗电流等原始图像数据；3.观测期间的原始导星数据（和多通道成像
仪共用）。这些数据格式都是FITS文件。"}

{"content": "MSC_MS 0级数据关键字PCOUNT是什么意思？", "summary": 在MSC_MS 0级数据头文件中，PCOUNT关键字表示伴随数据的参数数组的长度。在这个上下文中，对于原始数据，PCOUNT的样例值是0，表示没有伴随数据的参数数组。"}

#05 我的问题如下：

"""

{{此处替换成你上一步生成的问题}}

"""

#06 我的内容如下：

"""

{{此处替换成你的内容}}

"""
'''

# %% [markdown]
# # 文心一言配置

# %%
# 设置百度文心一言的API密钥和端点
API_KEY = "MxvHfAoOFUATRfpnohbnBAYb"
SECRET_KEY = "hOW7n2JSxNJQV1UvYxoUHmoNkmxGi3eB"

def get_access_token():
    """
    使用 AK，SK 生成鉴权签名（Access Token）
    :return: access_token，或是None(如果错误)
    """
    url = "https://aip.baidubce.com/oauth/2.0/token"
    params = {"grant_type": "client_credentials", "client_id": API_KEY, "client_secret": SECRET_KEY}
    return str(requests.post(url, params=params).json().get("access_token"))

# %% [markdown]
# # 问题生成函数

# %%
def generate_question(text_content, more=False):
    url = "https://aip.baidubce.com/rpc/2.0/ai_custom/v1/wenxinworkshop/chat/completions?access_token=" + get_access_token()
    content= "生成适合作为问答对的问题"
    if more:
        content = "尽可能多生成适合作为问答对的问题"
    prompt = prompt1.replace("{{此处替换成你的内容}}", text_content)
    payload = json.dumps({
        "messages": [
            {
                "role": "user",
                "content": content
            }
        ],
        "temperature": 0.95,
        "top_p": 0.8,
        "system":prompt
    })
    headers = {
        'Content-Type': 'application/json'
    }
    start_time = time.time()
    response = requests.request("POST", url, headers=headers, data=payload)
    x = json.loads(response.text)
    print("耗时", time.time() - start_time)
    print(x)
    if response.status_code == 200:
        return x['result']
    else:
        print(f"Error: {response.status_code}")
        print(response.content)
        return None

# %% [markdown]
# # 问答对生成函数

# %%
def generate_qa(text_content, question_text=None):
    url = "https://aip.baidubce.com/rpc/2.0/ai_custom/v1/wenxinworkshop/chat/completions?access_token=" + get_access_token()
    content= "拼成问答对"
    prompt = prompt2.replace("{{此处替换成你上一步生成的问题}}", question_text).replace("{{此处替换成你的内容}}", text_content)
    payload = json.dumps({
        "messages": [
            {
                "role": "user",
                "content": content
            }
        ],
        "temperature": 0.95,
        "top_p": 0.8,
        "system":prompt
    })
    headers = {
        'Content-Type': 'application/json'
    }
    start_time = time.time()
    response = requests.request("POST", url, headers=headers, data=payload)
    x = json.loads(response.text)
    print("耗时", time.time() - start_time)
    print(x)
    if response.status_code == 200:
        return x['result']
    else:
        print(f"Error: {response.status_code}")
        print(response.content)
        return None

# %% [markdown]
# # 将生成的问答对写入.txt文件

# %%
# 将分割后的文本块分别存储到多个txt文件中，并保存文件名到一个列表中
def write_to_file(content):
    txt_dir = 'generated_txt_files'
    timestamp = datetime.datetime.now().strftime("%Y%m%d%H%M%S")
    file_name = os.path.join(txt_dir, f"new_file_{timestamp}.txt")
    with open(file_name, "w", encoding="utf-8") as file:
        file.write(content)
    print("File 'new_file.txt' has been created and written.")

# %% [markdown]
# # 读取 pdf生成的txt文件

# %%
def read_file(file_name):
    try:
        with open(file_name, "r", encoding='utf-8') as file:
            content = file.read()
        return content
    except FileNotFoundError:
        print(f"File '{file_name}' not found.")

# %%
# 生成包含文件名的列表，从'text_file1.txt'到'text_file69.txt'
file_names = [f"txt_files/text_file{i}.txt" for i in range(1, 70)]

# 打印结果以验证
print(file_names)
# Out:
# ['txt_files/text_file1.txt', 'txt_files/text_file2.txt', 'txt_files/text_file3.txt', 'txt_files/text_file4.txt', 'txt_files/text_file5.txt', 'txt_files/text_file6.txt', 'txt_files/text_file7.txt', 'txt_files/text_file8.txt', 'txt_files/text_file9.txt', 'txt_files/text_file10.txt', 'txt_files/text_file11.txt', 'txt_files/text_file12.txt', 'txt_files/text_file13.txt', 'txt_files/text_file14.txt', 'txt_files/text_file15.txt', 'txt_files/text_file16.txt', 'txt_files/text_file17.txt', 'txt_files/text_file18.txt', 'txt_files/text_file19.txt', 'txt_files/text_file20.txt', 'txt_files/text_file21.txt', 'txt_files/text_file22.txt', 'txt_files/text_file23.txt', 'txt_files/text_file24.txt', 'txt_files/text_file25.txt', 'txt_files/text_file26.txt', 'txt_files/text_file27.txt', 'txt_files/text_file28.txt', 'txt_files/text_file29.txt', 'txt_files/text_file30.txt', 'txt_files/text_file31.txt', 'txt_files/text_file32.txt', 'txt_files/text_file33.txt', 'txt_files/text_file34.txt', 'txt_files/text_file35.txt', 'txt_files/text_file36.txt', 'txt_files/text_file37.txt', 'txt_files/text_file38.txt', 'txt_files/text_file39.txt', 'txt_files/text_file40.txt', 'txt_files/text_file41.txt', 'txt_files/text_file42.txt', 'txt_files/text_file43.txt', 'txt_files/text_file44.txt', 'txt_files/text_file45.txt', 'txt_files/text_file46.txt', 'txt_files/text_file47.txt', 'txt_files/text_file48.txt', 'txt_files/text_file49.txt', 'txt_files/text_file50.txt', 'txt_files/text_file51.txt', 'txt_files/text_file52.txt', 'txt_files/text_file53.txt', 'txt_files/text_file54.txt', 'txt_files/text_file55.txt', 'txt_files/text_file56.txt', 'txt_files/text_file57.txt', 'txt_files/text_file58.txt', 'txt_files/text_file59.txt', 'txt_files/text_file60.txt', 'txt_files/text_file61.txt', 'txt_files/text_file62.txt', 'txt_files/text_file63.txt', 'txt_files/text_file64.txt', 'txt_files/text_file65.txt', 'txt_files/text_file66.txt', 'txt_files/text_file67.txt', 'txt_files/text_file68.txt', 'txt_files/text_file69.txt']

# %% [markdown]
# # 主程序

# %%
file_names
# Out:
# ['new_txt_files/text_file1.txt',
#  'new_txt_files/text_file2.txt',
#  'new_txt_files/text_file3.txt',
#  'new_txt_files/text_file4.txt',
#  'new_txt_files/text_file5.txt',
#  'new_txt_files/text_file6.txt',
#  'new_txt_files/text_file7.txt',
#  'new_txt_files/text_file8.txt',
#  'new_txt_files/text_file9.txt',
#  'new_txt_files/text_file10.txt',
#  'new_txt_files/text_file11.txt',
#  'new_txt_files/text_file12.txt',
#  'new_txt_files/text_file13.txt']

# %%
for file in file_names:
    text_content = read_file(file)
    print(file)
    print ('text_content\n', text_content)
    question_text = generate_question(text_content=text_content, more=False)
    print('question_text\n', question_text)
    qa_text = generate_qa(text_content=text_content, question_text=question_text)
    print('qa_text\n', qa_text)
    write_to_file(qa_text)
# Out:
# new_txt_files/text_file1.txt
# text_content
#  编    号
# KSC-00-JK-0001-03.01
# 密    级
# 阶段标记
# Y
# 页    数
# 124
# 中国科学院国家天⽂台
#   中国科学院上海天⽂台
#   2024 年  3  ⽉ 20  ⽇
# 名  称：
# CSST 科学数据处理系统 0 级数据
# 输入需求和数据结构设计说明
# 编  写
# 校  对
# 审  核
# 标  审
# 批  准
# 会 签
# 文档修改记录
# 版本号
# 修改内容描述
# 修改人
# 修改日期备注
# 01.01
# 创建
# 汤静
# 21.12.01
# 02.01
# 修改
# 汤静
# 23.04.27
# 03.01
# 修改
# 汤静
# 24.03.27
# 1
# 目录
# 1.
# 范围.......................................................................................................... 1
# 1.1. 标识...................................................................................................... 1
# 1.2. 文档概述..............................................................................................1
# 2.
# 引用文档.................................................................................................. 1
# 3.
# 术语定义.................................................................................................. 1
# 4.
# 输入数据需求..........................................................................................2
# 5.
# 0 级数据结构接口设计和需求...............................................................4
# 5.1. 0 级数据需求概述...............................................................................4
# 5.2. 各模块0 级数据文件设计、命名及存储规范................................. 5
# 5.2.1.
# 主巡天模块（MSC）................................................................. 5
# 5.2.2.
# 多通道成像仪模块（MCI）......................................................7
# 5.2.3.
# 积分视场光谱仪模块（IFS）....................................................8
# 5.2.4.
# 星冕仪模块（CPIC）...............................................................10
# 5.2.5.
# 高灵敏度太赫兹模块（HSTDM）......................................... 11
# 5.3. 接口示意图........................................................................................14
# 5.3.1.
# 主巡天模块（MSC）............................................................... 14
# 5.3.2.
# 多通道成像仪模块（MCI）....................................................15
# 5.3.3.
# 积分视场光谱仪模块（IFS）..................................................16
# 5.3.4.
# 星冕仪模块（CPIC）...............................................................18
# 5.3.5.
# 高灵敏度太赫兹模块（HSTDM）......................................... 19
# 5.4. 接口名称和项目识别号....................................................................19
# 5.4.1.
# 接口需求....................................................................................19
# 5.4.2.
# 数据元素....................................................................................19
# 2
# 5.4.3.
# 数据元素与设施下传数据对应表........................................... 52
# 6.
# 导星仪0 级图像数据结构....................................................................52
# 6.1. 导星数据需求概述............................................................................52
# 6.2. 导星数据格式....................................................................................53
# 7.
# 其他工程辅助数据需求........................................................................53
# 7.1. 工程辅助数据需求概述....................................................................53
# 7.2. 其他工程辅助数据元素....................................................................53
# 3
# 图目录
# 图1. CSST 主巡天0 级数据存储文件夹结构示意图.............................7
# 图2. MCI 0 级数据存储文件夹结构示意图............................................8
# 图3. IFS 0 级数据存储文件夹结构示意图............................................10
# 图4. CPIC 0 级数据存储文件夹结构示意图........................................ 11
# 图5. HSTDM 0 级数据存储文件夹结构示意图................................... 13
# 图6. CSST 主巡天光学相机0 级数据结构示意图...............................14
# 图7. CSST 主巡天0 级数据image data 结构示意图........................... 14
# 图8. CSST 主巡天红外相机0 级数据结构示意图...............................15
# 图9. MCI 0 级数据结构示意图..............................................................15
# 图10. MCI 0 级数据image data 结构示意图........................................ 16
# 图11. IFS 0 级数据结构示意图..............................................................16
# 图12. IFS 0 级数据image data 结构示意图.......................................... 17
# 图13. CPIC 0 级数据结构示意图...........................................................18
# 图14. HSTDM 0 级数据结构示意图......................................................19
# 4
# 表目录
# 表1. 《初步技术要求》所规定的0 级数据主要内容.......................... 2
# 表2. 与0 级数据相匹配的工程辅助数据.............................................. 3
# 表3. 全局头文件关键字.........................................................................21
# 表4. 0 级数据头文件关键字（MSC_MS）.......................................... 25
# 耗时 18.968592166900635
# {'id': 'as-v3p2xviti3', 'object': 'chat.completion', 'created': 1722394418, 'result': '1. "CSST 科学数据处理系统 0 级数据的版本号是多少？"\n2. "《初步技术要求》规定的0级数据主要内容包含哪些？"\n3. "表3中列出的是哪些全局头文件关键字？"\n4. "MSC_MS 0级数据的主要头文件关键字有哪些？"\n5. "主巡天模块（MSC）的0级数据存储文件夹结构是如何示意图的？"\n6. "多通道成像仪模块（MCI）的0级数据存储在哪个示意图中描述？"\n7. "IFS模块的0级数据image data结构在哪个示意图中？"\n8. "星冕仪模块（CPIC）的0级数据存储文件夹结构示意图是哪一个？"\n9. "高灵敏度太赫兹模块（HSTDM）的0级数据结构示意图位于哪个图表？"\n10. "CSST主巡天红外相机的0级数据结构示意图的编号是什么？"', 'is_truncated': False, 'need_clear_history': False, 'finish_reason': 'normal', 'usage': {'prompt_tokens': 1233, 'completion_tokens': 181, 'total_tokens': 1414}}
# question_text
#  1. "CSST 科学数据处理系统 0 级数据的版本号是多少？"
# 2. "《初步技术要求》规定的0级数据主要内容包含哪些？"
# 3. "表3中列出的是哪些全局头文件关键字？"
# 4. "MSC_MS 0级数据的主要头文件关键字有哪些？"
# 5. "主巡天模块（MSC）的0级数据存储文件夹结构是如何示意图的？"
# 6. "多通道成像仪模块（MCI）的0级数据存储在哪个示意图中描述？"
# 7. "IFS模块的0级数据image data结构在哪个示意图中？"
# 8. "星冕仪模块（CPIC）的0级数据存储文件夹结构示意图是哪一个？"
# 9. "高灵敏度太赫兹模块（HSTDM）的0级数据结构示意图位于哪个图表？"
# 10. "CSST主巡天红外相机的0级数据结构示意图的编号是什么？"
# 耗时 55.11506128311157
# {'id': 'as-nr345hmz41', 'object': 'chat.completion', 'created': 1722394473, 'result': '```json\n[\n    {\n        "content": "CSST 科学数据处理系统 0 级数据的版本号是多少？",\n        "summary": "从文档内容中可以看到，CSST 科学数据处理系统 0 级数据的版本号是 03.01。"\n    },\n    {\n        "content": "《初步技术要求》规定的0级数据主要内容包含哪些？",\n        "summary": "《初步技术要求》所规定的0级数据主要内容在表1中描述，但具体内容在提供的文档中未直接列出。从文档结构来看，需要查看表1来得知具体内容。"\n    },\n    {\n        "content": "表3中列出的是哪些全局头文件关键字？",\n        "summary": "表3列出了全局头文件的关键字，但具体内容在提供的文档中未直接列出。需要查看表3来获取这些关键字。"\n    },\n    {\n        "content": "MSC_MS 0级数据的主要头文件关键字有哪些？",\n        "summary": "MSC_MS 0级数据的主要头文件关键字在表4中列出，但具体内容在提供的文档中未直接列出。需要查看表4来获取这些关键字。"\n    },\n    {\n        "content": "主巡天模块（MSC）的0级数据存储文件夹结构是如何示意图的？",\n        "summary": "主巡天模块（MSC）的0级数据存储文件夹结构示意图是图1。"\n    },\n    {\n        "content": "多通道成像仪模块（MCI）的0级数据存储在哪个示意图中描述？",\n        "summary": "多通道成像仪模块（MCI）的0级数据存储文件夹结构示意图是图2。"\n    },\n    {\n        "content": "IFS模块的0级数据image data结构在哪个示意图中？",\n        "summary": "IFS模块的0级数据image data结构在示意图图12中描述。"\n    },\n    {\n        "content": "星冕仪模块（CPIC）的0级数据存储文件夹结构示意图是哪一个？",\n        "summary": "星冕仪模块（CPIC）的0级数据存储文件夹结构示意图是图4。"\n    },\n    {\n        "content": "高灵敏度太赫兹模块（HSTDM）的0级数据结构示意图位于哪个图表？",\n        "summary": "高灵敏度太赫兹模块（HSTDM）的0级数据结构示意图位于图14。"\n    },\n    {\n        "content": "CSST主巡天红外相机的0级数据结构示意图的编号是什么？",\n        "summary": "CSST主巡天红外相机的0级数据结构示意图的编号是图8。"\n    }\n]\n```', 'is_truncated': False, 'need_clear_history': False, 'finish_reason': 'normal', 'usage': {'prompt_tokens': 1488, 'completion_tokens': 565, 'total_tokens': 2053}}
# qa_text
#  ```json
# [
#     {
#         "content": "CSST 科学数据处理系统 0 级数据的版本号是多少？",
#         "summary": "从文档内容中可以看到，CSST 科学数据处理系统 0 级数据的版本号是 03.01。"
#     },
#     {
#         "content": "《初步技术要求》规定的0级数据主要内容包含哪些？",
#         "summary": "《初步技术要求》所规定的0级数据主要内容在表1中描述，但具体内容在提供的文档中未直接列出。从文档结构来看，需要查看表1来得知具体内容。"
#     },
#     {
#         "content": "表3中列出的是哪些全局头文件关键字？",
#         "summary": "表3列出了全局头文件的关键字，但具体内容在提供的文档中未直接列出。需要查看表3来获取这些关键字。"
#     },
#     {
#         "content": "MSC_MS 0级数据的主要头文件关键字有哪些？",
#         "summary": "MSC_MS 0级数据的主要头文件关键字在表4中列出，但具体内容在提供的文档中未直接列出。需要查看表4来获取这些关键字。"
#     },
#     {
#         "content": "主巡天模块（MSC）的0级数据存储文件夹结构是如何示意图的？",
#         "summary": "主巡天模块（MSC）的0级数据存储文件夹结构示意图是图1。"
#     },
#     {
#         "content": "多通道成像仪模块（MCI）的0级数据存储在哪个示意图中描述？",
#         "summary": "多通道成像仪模块（MCI）的0级数据存储文件夹结构示意图是图2。"
#     },
#     {
#         "content": "IFS模块的0级数据image data结构在哪个示意图中？",
#         "summary": "IFS模块的0级数据image data结构在示意图图12中描述。"
#     },
#     {
#         "content": "星冕仪模块（CPIC）的0级数据存储文件夹结构示意图是哪一个？",
#         "summary": "星冕仪模块（CPIC）的0级数据存储文件夹结构示意图是图4。"
#     },
#     {
#         "content": "高灵敏度太赫兹模块（HSTDM）的0级数据结构示意图位于哪个图表？",
#         "summary": "高灵敏度太赫兹模块（HSTDM）的0级数据结构示意图位于图14。"
#     },
#     {
#         "content": "CSST主巡天红外相机的0级数据结构示意图的编号是什么？",
#         "summary": "CSST主巡天红外相机的0级数据结构示意图的编号是图8。"
#     }
# ]
# ```
# File 'new_file.txt' has been created and written.
# new_txt_files/text_file2.txt
# text_content
#  表5. 0 级数据头文件关键字（MSC_IR）............................................31
# 表6. 0 级数据头文件关键字（MCI）...................................................33
# 表7. 0 级数据头文件关键字（IFS）.....................................................43
# 表8. 0 级数据头文件关键字（CPIC）..................................................46
# 表9. 0 级数据头文件关键字（HSTDM）............................................ 49
# 表10. 各模块的共同需求.......................................................................53
# 表11. 主巡天需求...................................................................................54
# 表12. MCI 需求....................................................................................... 61
# 表13. IFS 需求......................................................................................... 63
# 表14. CPIC 需求......................................................................................66
# 表15. HSTDM 需求.................................................................................70
# 1
# 1. 范围
# 1.1. 标识
# KSC-00-JK-0001-03.01
# 1.2. 文档概述
# 本文档阐明载人航天工程巡天空间望远镜（China Space Station
# Telescope, CSST）数据处理系统对输入数据的内容和格式需求。
# 2. 引用文档
# 《载人空间站多功能光学设施科学数据处理系统实施方案》；
# 《CSST 数据处理系统初步技术要求》；
# 空间站数据结构表V0.2.xlsx；
# 《精密稳像子系统光纤通道数据内容说明》（上海技物所）
# 《多功能光学设施积分视场光谱仪数传接口数据单》（上海技物所）
# 《巡天空间望远镜坐标系及飞行姿态定义》
# 3. 术语定义
# CSST：（China Space Station Telescope）中国巡天空间望远镜；
# MSC：（Main Survey Camera）主巡天相机；
# MCI: （Multi Channel Imager）多通道成像仪；
# IFS：（Integral Field Spectroscopy）积分视场光谱仪；
# CPIC: （Cool Planet Imaging Coronagraph）系外行星成像星冕仪；
# HSTDM:
# （High Sensitivity Terahz Detection Module）高灵敏度太赫
# 兹模块；
# WFS: （Wavefront Sensor）波前传感器；
# 2
# FGS:
# （Fine Guidance Sensor）精细导星仪；
# FITS：（Flexible Image Transport System）普适图像传输系统；
# HDU：（Header data unit）文件头和数据单元；
# SHA：（Secure Hash Algorithm）安全散列算法；
# 4. 输入数据需求
# 按照《初步技术要求》，科学数据处理系统接收由科学与应用数据
# 中心提供的0 级数据产品和工程辅助数据产品。其中0 级数据产品是科
# 学数据处理系统分析流水线的输入，数据系统在此基础上，生成1 级和2
# 级科学数据产品，供科学用户使用。同时，科学数据系统需要依赖相应
# 的工程辅助数据检验科学数据质量，检测科学仪器性能长期演化，以改
# 进数据分析流水线，在轨定标方案并优化观测需求编排软件。
# 按照《初步技术要求》，0 级数据产品根据CSST 数据系统需求对
# CSST 原始数据经过数据提取，物理量转换，时间修正和添加相关标记生
# 成。根据《初步技术要求》，CSST 科学数据处理系统接收到数据类型由
# 表1 和表2 列出。其具体的数据内容需求和输入格式则在本文档第五节
# （5 个后端模块）、第六节（导星仪）和第七节（其他工程辅助数据）给
# 出。
# 表1. 《初步技术要求》所规定的0 级数据主要内容
# 序号
# 后端
# 模块
# 数据
# 级别
# 数据内容
# 数据
# 格式
# 1
# 巡天模块
# 多色成像
# /无缝光谱
# 0 级
# 主焦面原始曝光图像
# FITS
# 2
# 0 级
# 多色成像参考图像，包括偏置、平场、暗
# 电流等原始图像数据
# FITS
# 3
# 0 级
# 无缝光谱参考图像，包括暗电流、偏置、
# 同一光谱带宽内不同波长的平场等原始图
# FITS
# 3
# 像文件
# 4
# 0 级
# 观测中间一些固定时刻的精密导星仪数
# 据、天体定标组件、短波红外组件、波前
# 传感器原始数据
# FITS
# 5
# 多通道成
# 像仪
# 0 级
# 观测目标的原始曝光图像
# FITS
# 6
# 0 级
# 参考图像，包括偏置、平场、暗电流等原
# 始图像数据
# FITS
# 7
# 0 级
# 观测期间的原始导星数
# FITS
# 8
# 积分视场
# 光谱仪
# 0 级
# 观测目标的原始曝光图像
# FITS
# 0 级
# 参考图像，包括偏置、平场、暗电流等原
# 始图像数据
# FITS
# 9
# 0 级
# 观测期间的原始导星数据（和多通道成像
# 仪共用）
# FITS
# 10
# 系外行星
# 成像星冕
# 仪
# 0 级
# 观测目标的原始曝光图像
# FITS
# 11
# 0 级
# 参考图像，包括偏置、平场、暗电流、天
# 空背景等原始图像数据
# FITS
# 12
# 0 级
# 观测期间的原始导星数据
# FITS
# 13
# 太赫兹模
# 块
# 0 级
# 原始谱线数据（每条谱线通道，包含积分
# 开始、结束时间或者积分时间）
# 二进制
# 文件
# 14
# 0 级
# 太赫兹模块状态信息（探测器、本振源、
# 低温放大器、常温中频、数字频谱仪、中
# 频输出总功率、校准黑体温度、校准镜的
# 位置、观测模式、观测频率及边带等状态
# 信息）
# 二进制
# 文件
# 表2. 与0 级数据相匹配的工程辅助数据
# 序号
# 数据类别
# 数据内容
# 数据来源
# 1
# 空间环境
# 空间环境预报数据、空间环境在轨实测数据产品
# 科学与应
# 用数据中
# 4
# 5. 0 级数据结构接口设计和需求
# 5.1. 0 级数据需求概述
# 按照《CSST 数据处理系统初步技术要求》0 级数据是对CSST 原始
# 数据进行下行传输链路解帧格式、图像和其他数据提取、物理量转换、
# 时间修正和标记等处理生成的。0 级数据文件内容包括相应模块的观测数
# 据、定标数据，观测设定（如设定曝光时间，平场灯档位信息等），和
# 观测相关的工程遥测数据（如望远镜姿态和位置），其中一部分数据需
# 要通过地面解算转换为天文分析所用的物理量（如从星上时间转化为天
# 文使用的儒略日期）。此外，如望远镜名称（总为“CSST”），探测器感
# 光区域大小等数据为地面预先写定内容，不涉及观测数据和工程辅助数
# 据，但按照天文观测一般习惯也为0 级数据文件内容的一部分。
# 数据产品
# 心提供
# 2
# 工程勤务
# 数据产品
# 星上时、天地时差；后处理的轨道数据、姿态数
# 据、望远镜指向等
# 科学与应
# 用数据中
# 心生产并
# 提供
# 3
# 有效载荷关键工程参数（如温度测点、电压电
# 流、摆镜位置、望远镜调焦、主动光学调整状
# 态，望远镜遮光盖、模块快门状态、后端模块工
# 作状态等）
# 4
# 任务辅助
# 数据产品
# 轨道预报数据、阴影阳照、日月位置区、过站预
# 报、干扰源、过SAA 区、事件预报等
# 有效载荷
# 运控管理
# 系统提供
# 5
# 测控资源、数传资源、功耗资源、存储资源、计
# 算资源等初始可用资源
# 6
# 数据下传计划（包括常规遥测和数传数据）
# 7
# 载荷工作计划（含观测任务安排记录信息）
# 8
# 下行数据完整性质量报告
# 9
# 有效载荷健康状态
# 5
# 按照《CSST 数据处理系统初步技术要求》0 级数据文件的格式为
# FITS（Flexible Image Transport System，普适图像传输系统）格式。
# 5.2. 各模块0 级数据文件设计、命名及存储规范
# 5.2.1.
# 主巡天模块（MSC）
# CSST 主巡天焦面光学相机总共有31 个9216×9232 的探测器，其中
# 18 个用作多波段成像（u, g, r, i, z 各2 个，NUV, y 各4 个），12 个用作
# 无缝光谱（GU, GV, GI 各4 个），1 个用于天体定标。红外相机总共有8
# 个640×512 的探测器，其中4 个用作近红外波段成像（ƴ', Ʋ'各2 个），
# 4 个用作无缝光谱（ƴ', Ʋ'各2 个），ƴ'指0.9-1.3 μǑ, Ʋ'指1.3-1.7 μǑ。
# 每个探测器每次数据读出后的数据对象（以下简称为对象）称为0 级数
# 据。
# 每个探测器单次曝光的读出数据存储为一个fits 文件。文件名命名规
# 则为CSST_MSC_CAMERA_TYPE_YYYYMMDDhhmmss_YYYYMM
# DDhhmmss_OBSID_MM_L0_VER.fits，其中：
# CAMERA 为相机名称, MS 表示光学相机，IR 表示红外相机。
# TYPE 表示目标类型，共有6 种类型，包括3 种内部标
# 模式BIAS（本底）/ DARK（暗场）/ FLAT （平场），2 种外部定标模
# 式CALS（定标星）和CALF（定标星场），和1 种科学观测模式SCI
# （巡天观测）。
# YYYYMMDD 是八位数观测日期，例如20240518，表示2024 年5
# 月18 日。
# hhmmss 是六位数UTC 观测时间（开始时间／结束时间），例如
# 122838，表示12 点28 分38 秒。
# OBSID 是观测编号，X+OBSTYPE+8 位数字，其中X=1（主巡天），
# 2（MCI），3（IFS），4（CPIC），5（HSTDM）。观测类型OBSTYPE
# 6
# 为2 位数字，由各模块自行定义（可以比TYPE 分类更细）。8 位数字为
# 8 位数曝光编号，例如00029816。详见附件《0 级数据元素与设施下传数
# 据对应表》的备注。
# MM 为数据对应的两位数的探测器编号，例如06，天体定标组件编
# 号为31。有相同观测日期和时间的对象为同一次曝光观测的数据，有相
# 同曝光编号的对象覆盖同一观测天区。
# L0 表示文件为0 级科学观测数据。
# VER 是版本号，3 个字符，V+阿拉伯数字，取值范围为V01~V99。
# 首次生成取值01，再次生成取02，以此类推。
# 举例如下：CSST_MSC_MS_SCI_20240101120000_2024010112
# 0230_10100000012_10_L0_V01.fits，表示主巡天模块中的主巡天相机在
# 2024 年1 月1 日UTC 时间12:00:00 观测（曝光150s）的曝光编号为
# 00000012 的10 号探测器的0 级科学数据文件。
# 耗时 18.045247077941895
# {'id': 'as-sa406ikube', 'object': 'chat.completion', 'created': 1722394491, 'result': '1. CSST主巡天模块中的探测器数量是多少？\n2. MSC模块中用于无缝光谱的探测器数量是多少？\n3. MSC模块中的红外相机探测器数量及其用途是什么？\n4. 0级数据文件通常采用什么格式？\n5. MSC 0级数据文件命名规则中的"TYPE"字段表示什么？\n6. CSST_MSC_CAMERA_TYPE_YYYYMMDDhhmmss_YYYYMMDDhhmmss_OBSID_MM_L0_VER.fits文件名中的"OBSID"字段是如何构成的？\n7. "MM"在MSC 0级数据文件命名规则中代表什么？\n8. MSC 0级数据文件的"VER"字段有什么作用？\n9. 如何通过文件名判断CSST 0级数据文件是由哪个模块生成的？\n10. MSC 0级数据文件命名中的"YYYYMMDD"和"hhmmss"分别代表什么？', 'is_truncated': False, 'need_clear_history': False, 'finish_reason': 'normal', 'usage': {'prompt_tokens': 2622, 'completion_tokens': 194, 'total_tokens': 2816}}
# question_text
#  1. CSST主巡天模块中的探测器数量是多少？
# 2. MSC模块中用于无缝光谱的探测器数量是多少？
# 3. MSC模块中的红外相机探测器数量及其用途是什么？
# 4. 0级数据文件通常采用什么格式？
# 5. MSC 0级数据文件命名规则中的"TYPE"字段表示什么？
# 6. CSST_MSC_CAMERA_TYPE_YYYYMMDDhhmmss_YYYYMMDDhhmmss_OBSID_MM_L0_VER.fits文件名中的"OBSID"字段是如何构成的？
# 7. "MM"在MSC 0级数据文件命名规则中代表什么？
# 8. MSC 0级数据文件的"VER"字段有什么作用？
# 9. 如何通过文件名判断CSST 0级数据文件是由哪个模块生成的？
# 10. MSC 0级数据文件命名中的"YYYYMMDD"和"hhmmss"分别代表什么？
# 耗时 76.67963480949402
# {'id': 'as-0rtgyj9vxt', 'object': 'chat.completion', 'created': 1722394568, 'result': '```json\n[\n    {\n        "content": "CSST主巡天模块中的探测器数量是多少？",\n        "summary": "CSST主巡天焦面光学相机总共有31个9216×9232的探测器，其中18个用于多波段成像，12个用于无缝光谱，还有1个用于天体定标。"\n    },\n    {\n        "content": "MSC模块中用于无缝光谱的探测器数量是多少？",\n        "summary": "MSC模块中用于无缝光谱的探测器数量是12个，分别为GU, GV, GI各4个。"\n    },\n    {\n        "content": "MSC模块中的红外相机探测器数量及其用途是什么？",\n        "summary": "MSC模块中的红外相机总共有8个640×512的探测器，其中4个用于近红外波段成像（ƴ\', Ʋ\'各2个），4个用于无缝光谱（ƴ\', Ʋ\'各2个）。"\n    },\n    {\n        "content": "0级数据文件通常采用什么格式？",\n        "summary": "0级数据文件通常采用FITS（Flexible Image Transport System，普适图像传输系统）格式。"\n    },\n    {\n        "content": "MSC 0级数据文件命名规则中的\\"TYPE\\"字段表示什么？",\n        "summary": "MSC 0级数据文件命名规则中的\\"TYPE\\"字段表示目标类型，共有6种类型，包括3种内部标定模式（BIAS/DARK/FLAT）、2种外部定标模式（CALS/CALF）和1种科学观测模式（SCI）。"\n    },\n    {\n        "content": "CSST_MSC_CAMERA_TYPE_YYYYMMDDhhmmss_YYYYMMDDhhmmss_OBSID_MM_L0_VER.fits文件名中的\\"OBSID\\"字段是如何构成的？",\n        "summary": "\\"OBSID\\"是观测编号，格式为X+OBSTYPE+8位数字，其中X=1（主巡天），OBSTYPE为2位数字（由各模块自行定义），8位数字为曝光编号。"\n    },\n    {\n        "content": "\\"MM\\"在MSC 0级数据文件命名规则中代表什么？",\n        "summary": "\\"MM\\"在MSC 0级数据文件命名规则中代表数据对应的两位数的探测器编号。"\n    },\n    {\n        "content": "MSC 0级数据文件的\\"VER\\"字段有什么作用？",\n        "summary": "MSC 0级数据文件的\\"VER\\"字段是版本号，用于标识文件的版本，格式为V+阿拉伯数字，取值范围为V01~V99。"\n    },\n    {\n        "content": "如何通过文件名判断CSST 0级数据文件是由哪个模块生成的？",\n        "summary": "通过文件名中的OBSID字段的第一个字符（X）可以判断CSST 0级数据文件是由哪个模块生成的，其中X=1代表主巡天模块，2代表多通道成像仪，3代表积分视场光谱仪，4代表系外行星成像星冕仪，5代表高灵敏度太赫兹模块。"\n    },\n    {\n        "content": "MSC 0级数据文件命名中的\\"YYYYMMDD\\"和\\"hhmmss\\"分别代表什么？",\n        "summary": "\\"YYYYMMDD\\"是八位数观测日期，表示观测的年月日；\\"hhmmss\\"是六位数UTC观测时间（开始时间/结束时间），表示观测的具体时间。"\n    }\n]\n```', 'is_truncated': False, 'need_clear_history': False, 'finish_reason': 'normal', 'usage': {'prompt_tokens': 2890, 'completion_tokens': 766, 'total_tokens': 3656}}
# qa_text
#  ```json
# [
#     {
#         "content": "CSST主巡天模块中的探测器数量是多少？",
#         "summary": "CSST主巡天焦面光学相机总共有31个9216×9232的探测器，其中18个用于多波段成像，12个用于无缝光谱，还有1个用于天体定标。"
#     },
#     {
#         "content": "MSC模块中用于无缝光谱的探测器数量是多少？",
#         "summary": "MSC模块中用于无缝光谱的探测器数量是12个，分别为GU, GV, GI各4个。"
#     },
#     {
#         "content": "MSC模块中的红外相机探测器数量及其用途是什么？",
#         "summary": "MSC模块中的红外相机总共有8个640×512的探测器，其中4个用于近红外波段成像（ƴ', Ʋ'各2个），4个用于无缝光谱（ƴ', Ʋ'各2个）。"
#     },
#     {
#         "content": "0级数据文件通常采用什么格式？",
#         "summary": "0级数据文件通常采用FITS（Flexible Image Transport System，普适图像传输系统）格式。"
#     },
#     {
#         "content": "MSC 0级数据文件命名规则中的\"TYPE\"字段表示什么？",
#         "summary": "MSC 0级数据文件命名规则中的\"TYPE\"字段表示目标类型，共有6种类型，包括3种内部标定模式（BIAS/DARK/FLAT）、2种外部定标模式（CALS/CALF）和1种科学观测模式（SCI）。"
#     },
#     {
#         "content": "CSST_MSC_CAMERA_TYPE_YYYYMMDDhhmmss_YYYYMMDDhhmmss_OBSID_MM_L0_VER.fits文件名中的\"OBSID\"字段是如何构成的？",
#         "summary": "\"OBSID\"是观测编号，格式为X+OBSTYPE+8位数字，其中X=1（主巡天），OBSTYPE为2位数字（由各模块自行定义），8位数字为曝光编号。"
#     },
#     {
#         "content": "\"MM\"在MSC 0级数据文件命名规则中代表什么？",
#         "summary": "\"MM\"在MSC 0级数据文件命名规则中代表数据对应的两位数的探测器编号。"
#     },
#     {
#         "content": "MSC 0级数据文件的\"VER\"字段有什么作用？",
#         "summary": "MSC 0级数据文件的\"VER\"字段是版本号，用于标识文件的版本，格式为V+阿拉伯数字，取值范围为V01~V99。"
#     },
#     {
#         "content": "如何通过文件名判断CSST 0级数据文件是由哪个模块生成的？",
#         "summary": "通过文件名中的OBSID字段的第一个字符（X）可以判断CSST 0级数据文件是由哪个模块生成的，其中X=1代表主巡天模块，2代表多通道成像仪，3代表积分视场光谱仪，4代表系外行星成像星冕仪，5代表高灵敏度太赫兹模块。"
#     },
#     {
#         "content": "MSC 0级数据文件命名中的\"YYYYMMDD\"和\"hhmmss\"分别代表什么？",
#         "summary": "\"YYYYMMDD\"是八位数观测日期，表示观测的年月日；\"hhmmss\"是六位数UTC观测时间（开始时间/结束时间），表示观测的具体时间。"
#     }
# ]
# ```
# File 'new_file.txt' has been created and written.
# new_txt_files/text_file3.txt
# text_content
#  0 级数据对象存储于文件夹中，文件夹命名按照从设备总体到不同终
# 端的不同功能层层递进的原则建立。以主巡天焦面为例，文件夹的目录
# 结构如图1 所示。CSST_L0 表示CSST 的0 级数据，MSC 表示主巡天模
# 块，SCI 表示科学观测数据，CAL 表示定标数据，Params 表示遥测参数，
# MJD 表示观测开始时间的MJD 取整（例如58849），OBSID 表示观测
# 编号，MS（Main Survey）表示主巡天光学相机，IR（Infrared）表示主巡
# 天红外相机。其中，科学观测数据存储于SCI 目录下，内部和外部定标
# 数据存储于CAL 目录下，工程辅助数据（表10 和表11）存储于Params
# 目录下。示例文件名（包括路径）：
# CSST_L0/MSC/SCI/60310/10100000012/MS/CSST_MSC_MS_SCI_2024010
# 1120000_20240101120230_10100000012_10_L0_V01.fits
# 7
# 5.2.2.
# 多通道成像仪模块（MCI）
# MCI 采用分色片将入射光分成紫外光和可见光，可见光进一步分成
# 红光和绿光，分别到达各自的滤光片组和探测器（大小为9216×9232）。
# MCI 采用滤光轮设计，总共携带30 个滤光片（紫外通道10 个细分波段，
# 可见光通道20 个细分波段）。每个探测器每次数据读出后的数据对象称
# 为0 级数据。
# 每个探测器单次曝光（含BIAS 读取等定标过程）的读出数据存储为
# 一个fits 文件。文件名命名规则为CSST_MCI_CHANNEL_TYPE_YYYY
# MMDDhhmmss_YYYYMMDDhhmmss _OBSID_FILTER_L0_VER.fits，其
# 中：
# CHANNEL 为通道编号，2 位字符串，C1，C2，C3 代表3 个通道。
# TYPE 表示目标类型，共有9 种类型，包括3 种内部定标模式BIAS
# （本底）/ DARK（暗场）/ FLAT（平场），2 种外部定标模式CALS
# （定标星）/ CALF（定标天区）和4 种科学目标模式EXDF（极深场）/
# PI（PI 项目）/ TRNS（暂现源观测）/ COMB（用于联合观测模式下MCI
# 的被动曝光）。
# YYYYMMDD 是八位数观测日期，说明同上。
# 图1. CSST 主巡天0 级数据存储文件夹结构示意图
# 8
# hhmmss 是六位数UTC 观测时间，说明同上。
# OBSID 说明同上。
# FILTER 为滤光片编号，2 位整数，例如06。
# L0 说明同上。
# VER 说明同上。
# 举例如下：CSST_MCI_C1_CALS_20240101120000_20240101
# 120230_21000000012_01_L0_V01.fits，该文件表示MCI 在2024 年1 月1
# 日UTC 时间12:00:00 对定标星观测（以曝光150s 为例）的曝光编号为
# 00000012 的1 通道的1 号滤光片的0 级数据。
# 0 级数据对象存储于文件夹中，文件夹命名层级如图2 所示。其中，
# 科学目标数据存储于SCI 目录下，内部和外部定标数据存储于CAL 目录
# 下，工程辅助数据（表10 和表12）存储于Params 目录下。示例文件名
# （包括路径）：CSST_L0/MCI/SCI/60310/21000000012/CSST_MCI_C1_
# CALS_20240101120000_20240101120230_21000000012_01_L0_V01.fits
# 5.2.3.
# 积分视场光谱仪模块（IFS）
# IFS 终端有两块CCD 探测器，按照光谱观测时候的波长覆盖范围分
# 为蓝端（大小为4kx4k）和红端（大小为6kx6k）。每个探测器每次数据
# 读出后的数据对象称为0 级数据。
# 图2. MCI 0 级数据存储文件夹结构示意图
# 9
# 每个探测器单次曝光（含BIAS 读取等定标过程）的读出数据存储为
# 一个fits 文件。文件名命名规则为CSST_IFS_CAMERA_TYPE_YYYY
# MMDDhhmmss_YYYYMMDDhhmmss_OBSID_CAMERA_L0_VER.fits ，
# 其中：
# CAMERA 为光谱仪编号，1 位字符串，红端为“R”，蓝端为“B”。
# TYPE 为目标类型，共有5 种类型，包括4 种内部定标模式BIAS
# （本底）/ DARK（暗场）/ FLAT（平场）/ LAMP（灯谱）和2 种科学目
# 标模式SCI（IFS 为主要观测设备时的科学观测目标）/ COMB（IFS 为辅
# 助观测设备时的观测目标）。
# YYYYMMDD 是八位数观测日期，说明同上。
# hhmmss 是六位数UTC 观测时间，说明同上。一个obsid 的观测中，
# 如果涉及多帧观测，则第一个hhmmss 为第一帧数据开始观测时间，第二
# 个hhmmss 定义为最后一帧数据的观测结束时间。
# OBSID 说明同上。
# L0 说明同上。
# VER 说明同上。
# 举例如下：CSST_IFS_R_SCI_20240101120000_20240101120230_301
# 00000012_R_L0_V01.fits，该文件表示IFS 在2024 年1 月1 日UTC 时间
# 12:00:00 对科学观测目标（以曝光150s 为例）的曝光编号为00000012 的
# 红端CCD 记录的0 级数据。
# 0 级数据对象存储于文件夹中，文件夹命名层级如图3 所示。其中，
# 科学目标数据存储于SCI 目录下，内部定标数据存储于CAL 目录下，工
# 程辅助数据（表10 和表13）存储于Params 目录下。示例文件名（包括
# 路径）：CSST_L0/IFS/SCI/60310/ CSST_IFS_R_SCI_20240101120000_20
# 240101120230_30100000012_R_L0_V01.fits
# 10
# 5.2.4.
# 系外行星成像星冕仪（CPIC）
# 星冕仪数据处理系统0 级数据包括可见光和红外波段观测数据。两
# 种数据除包括星冕仪模块可见光相机、近红外相机拍摄的图像外，还需
# 要使用星冕仪模块采集到的相机辅助数据、波前相机数据、定标数据、
# 遥测数据、工程参数，以及平台相关的指向、位置等数据。
# 星冕仪的可见光和红外相机各包含一个探测器。地面发送一次曝光
# 指令（对应一个OBSID），工作探测器（可见光／红外）会拍摄一幅或
# 多幅图像。这些图像储存在一个fits 文件中。文件名命名规则为
# CSST_CPIC_CAMERA_TYPE_YYYYMMDDhhmmss_YYYYMMDDhhm
# mss_OBSID_X_L0_VER.fits，其中：
# CAMERA 为相机名称,
# VIS 表示可见光相机，NIR 表示近红外相机。
# TYPE 表示目标类型，共有8 种类型，包括5 种定标模式
# BIAS（本底）/ DARK（暗场）/ FLAT（平场）/ BKG（天空背景定标）/
# LASER（内部激光器定标）和3 种科学目标模式SCI（科学观测）/ DSF
# （密集星场观测）/ CALS（定标星观测）。
# YYYYMMDD 是八位数观测日期，说明同上。
# hhmmss 是六位数UTC 观测时间，说明同上。
# 图3. IFS 0 级数据存储文件夹结构示意图
# 11
# OBSID 说明同上。
# X 为补齐文件名格式，无实际信息。
# L0 说明同上。
# VER 说明同上。
# 举例如下：CSST_CPIC_VIS_SCIE_20240101120000_20240101120230
# _40100000012_X_L0_V01.fits ，该文件表示CPIC 在2024 年1 月1 日
# UTC 时间12:00:00 对科学观测目标（以曝光150s 为例）的曝光编号为
# 00000012 的可见光波段观测的0 级数据。
# 0 级数据对象存储于文件夹中，文件夹命名层级如图4 所示。其中，
# 科学目标数据存储于SCI 目录下，定标数据存储于CAL 目录下，工程辅
# 助数据（表10 和表14）存储于Params 目录下。示例文件名（包括路
# 径）：CSST_L0/CPIC/SCI/60310/VIS/CSST_CPIC_VIS_SCI_2024010112
# 0000_20240101120230_40100000012_X_L0_V01.fits
# 5.2.5.
# 高灵敏度太赫兹模块（HSTDM）
# CSST 高灵敏度太赫兹模块总共有3 个探测器，探测器1，2 工作频
# 率为410-510 GHz，探测器3 不再使用（最初设计的工作频率为520-630
# 图4. CPIC 0 级数据存储文件夹结构示意图
# 12
# GHz）。单点观测时，探测器1 和2 只有一个观测，采样时间是1 s；
# OTF 观测时，1 和2 同时工作，采样时间是0.25 s。
# 地面发出一次观测指令（对应一个OBSID），每个探测器的读出数
# 据包含4 个类型：对目标源进行观测时，产生目标源的观测数据
# （ON_SCI）和黑体校准数据（ON_BLK）；对目标源附近的OFF 点进行
# 观测时（参考背景），产生OFF 点的观测数据（OFF_SCI）和黑体校准
# 数据（OFF_BLK）。此外，还有4 种定标模式CAL_PNT（指向校准观
# 测）/ CAL_FRQ（频率校准观测）/ CAL_PAT（方向图校准观测）/
# CAL_EFF（观测效率校准）。一次采样时间里的数据存储为一个fits 文
# 件。文件名命名规则形为CSST_HSTDM_TYPE1_TYPE2_YYYYMMDD
# hhmmss_YYYYMMDDhhmmss_OBSID_MM-NNNN_L0_VER.fits，其中：
# TYPE1 表示对目标源（ONS ）或OFF 点（OFF ）或定标观测
# （CAL）。
# TYPE2 表示科学数据（SCI）或黑体校准数据（BLK）或定标类型
# （PNT/FRQ/PAT/EFF），例如ONS_BLK, 表示对目标源进行观测时的黑
# 体校准数据。
# YYYYMMDD 是八位数观测日期，说明如上。
# hhmmss 是六位数UTC 观测时间，说明如上。
# OBSID 说明同上。
# MM 为数据对应的探测器编号，取值为01，02，03（不再使用）。
# NNNN 用来标记一个OBSID 里不同采样点的文件，取值为0001，
# 0002，0003，…，9999。
# L0 说明同上。
# VER 说明同上。
# 举例如下：CSST_HSTDM_ONS_BLK_20240101120000_2024010112
# 0230_50100000012_01-0001_L0_V01.fits，表示太赫兹模块在2024 年1 月
# 13
# 1 日UTC 时间12:00:00 对科学观测目标（以曝光150s 为例）的曝光编号
# 为00000012 的使用探测器01 观测的第1 个采样点的黑体校准0 级数据
# 文件。
# 0 级数据对象存储于文件夹中，文件夹命名层级如图5 所示。其中，
# ONS_SCI 数据存储于SCI 目录下，ONS_BLK, OFF_SCI, OFF_BLK,
# CAL_PNT, CAL_FRQ, CAL_PAT, CAL_EFF 数据存储于CAL 目录下，工
# 程辅助数据（表10 和表15）存储于Params 目录下。示例文件名（包括
# 路径）：CSST_L0/HSTDM/SCI/60310/ CSST_HSTDM_ONS_BLK_202401
# 01120000_20240101120230_50100000012_01-0001_L0_V01.fits
# 如果对象利用fpack（https://heasarc.gsfc.nasa.gov/fitsio/fpack/，版本
# 号=1.7.0）工具进行压缩保存，文件名后缀应为.fits.fz。文件索引号通过
# 计算文件名的SHA256 散列值给出，取散列值的前128bit 为文件索引号。
# 对象数据格式遵循FITS 标准，需要保证现有的主流FITS 格式文件读写
# 软件（至少应当包括astropy.io.fits 和libcfitsio）均能操作对象。
# 图5. HSTDM 0 级数据存储文件夹结构示意图
# 14
# 5.3. 接口示意图
# 5.3.1.
# 主巡天模块（MSC）
# 光学数据文件对象接口如图6 所示：
# 文件对象包含两个HDU，其中primary HDU（图中的global header）
# 只包含望远镜的位置姿态信息。同一次观测所有波段测光和无缝光谱
# 图像global header 内容基本一致。对象有一个图像扩展（图中的raw
# image），raw image 的header 包含探测器相关信息、WCS 相关数据、
# 耗时 14.50758409500122
# {'id': 'as-jbhxjfki71', 'object': 'chat.completion', 'created': 1722394583, 'result': '1. 主巡天模块0级数据的文件夹命名结构是怎样的？\n2. MCI模块中，每个探测器单次曝光的数据存储在什么文件中？\n3. IFS模块的0级数据文件名中，CAMERA字段代表什么？\n4. CPIC模块的可见光相机和红外相机在0级数据文件名中分别如何表示？\n5. HSTDM模块中，探测器的黑体校准数据在文件名中如何标识？\n6. 如果对象数据使用fpack工具压缩，文件后缀是什么？\n7. 文件索引号是如何从文件名中计算得到的？\n8. FITS格式文件需要支持哪些主流读写软件？\n9. MSC模块的光学数据文件对象包含多少个HDU？\n10. MSC模块的primary HDU中主要包含哪些信息？', 'is_truncated': False, 'need_clear_history': False, 'finish_reason': 'normal', 'usage': {'prompt_tokens': 3420, 'completion_tokens': 158, 'total_tokens': 3578}}
# question_text
#  1. 主巡天模块0级数据的文件夹命名结构是怎样的？
# 2. MCI模块中，每个探测器单次曝光的数据存储在什么文件中？
# 3. IFS模块的0级数据文件名中，CAMERA字段代表什么？
# 4. CPIC模块的可见光相机和红外相机在0级数据文件名中分别如何表示？
# 5. HSTDM模块中，探测器的黑体校准数据在文件名中如何标识？
# 6. 如果对象数据使用fpack工具压缩，文件后缀是什么？
# 7. 文件索引号是如何从文件名中计算得到的？
# 8. FITS格式文件需要支持哪些主流读写软件？
# 9. MSC模块的光学数据文件对象包含多少个HDU？
# 10. MSC模块的primary HDU中主要包含哪些信息？
# 耗时 78.34967470169067
# {'id': 'as-35d57hfqed', 'object': 'chat.completion', 'created': 1722394663, 'result': '```json\n[\n    {\n        "content": "主巡天模块0级数据的文件夹命名结构是怎样的？",\n        "summary": "主巡天模块0级数据的文件夹命名结构从设备总体到不同终端的不同功能层层递进，例如：CSST_L0/MSC/SCI/MJD/OBSID/MS 或 IR，其中CSST_L0 表示CSST的0级数据，MSC表示主巡天模块，SCI表示科学观测数据，MJD表示观测开始时间的MJD取整，OBSID表示观测编号，MS表示主巡天光学相机，IR表示主巡天红外相机。"\n    },\n    {\n        "content": "MCI模块中，每个探测器单次曝光的数据存储在什么文件中？",\n        "summary": "MCI模块中，每个探测器单次曝光（含BIAS读取等定标过程）的读出数据存储为一个FITS文件。文件名命名规则为CSST_MCI_CHANNEL_TYPE_YYYYMMDDhhmmss_YYYYMMDDhhmmss_OBSID_FILTER_L0_VER.fits，其中CHANNEL、TYPE、YYYYMMDD、hhmmss、OBSID、FILTER、L0和VER分别代表通道编号、目标类型、观测日期、观测时间、观测编号、滤光片编号、L0级数据和版本号。"\n    },\n    {\n        "content": "IFS模块的0级数据文件名中，CAMERA字段代表什么？",\n        "summary": "IFS模块的0级数据文件名中，CAMERA字段代表光谱仪编号，红端CCD为“R”，蓝端CCD为“B”。"\n    },\n    {\n        "content": "CPIC模块的可见光相机和红外相机在0级数据文件名中分别如何表示？",\n        "summary": "CPIC模块的0级数据文件名中，可见光相机和红外相机分别用“VIS”和“NIR”表示。"\n    },\n    {\n        "content": "HSTDM模块中，探测器的黑体校准数据在文件名中如何标识？",\n        "summary": "HSTDM模块中，探测器的黑体校准数据在文件名中通过TYPE2字段标识为“BLK”，如CSST_HSTDM_ONS_BLK_YYYYMMDDhhmmss_YYYYMMDDhhmmss_OBSID_MM-NNNN_L0_VER.fits，表示对目标源进行观测时的黑体校准数据。"\n    },\n    {\n        "content": "如果对象数据使用fpack工具压缩，文件后缀是什么？",\n        "summary": "如果对象数据使用fpack工具压缩，文件后缀应为.fits.fz。"\n    },\n    {\n        "content": "文件索引号是如何从文件名中计算得到的？",\n        "summary": "文件索引号通过计算文件名的SHA256散列值给出，取散列值的前128bit为文件索引号。"\n    },\n    {\n        "content": "FITS格式文件需要支持哪些主流读写软件？",\n        "summary": "FITS格式文件需要支持的主流读写软件至少应当包括astropy.io.fits和libcfitsio。"\n    },\n    {\n        "content": "MSC模块的光学数据文件对象包含多少个HDU？",\n        "summary": "MSC模块的光学数据文件对象包含两个HDU，其中一个是primary HDU，另一个是图像扩展（raw image）。"\n    },\n    {\n        "content": "MSC模块的primary HDU中主要包含哪些信息？",\n        "summary": "MSC模块的primary HDU主要包含望远镜的位置姿态信息。同一次观测所有波段测光和无缝光谱图像的global header内容基本一致。"\n    }\n]\n```', 'is_truncated': False, 'need_clear_history': False, 'finish_reason': 'normal', 'usage': {'prompt_tokens': 3652, 'completion_tokens': 791, 'total_tokens': 4443}}
# qa_text
#  ```json
# [
#     {
#         "content": "主巡天模块0级数据的文件夹命名结构是怎样的？",
#         "summary": "主巡天模块0级数据的文件夹命名结构从设备总体到不同终端的不同功能层层递进，例如：CSST_L0/MSC/SCI/MJD/OBSID/MS 或 IR，其中CSST_L0 表示CSST的0级数据，MSC表示主巡天模块，SCI表示科学观测数据，MJD表示观测开始时间的MJD取整，OBSID表示观测编号，MS表示主巡天光学相机，IR表示主巡天红外相机。"
#     },
#     {
#         "content": "MCI模块中，每个探测器单次曝光的数据存储在什么文件中？",
#         "summary": "MCI模块中，每个探测器单次曝光（含BIAS读取等定标过程）的读出数据存储为一个FITS文件。文件名命名规则为CSST_MCI_CHANNEL_TYPE_YYYYMMDDhhmmss_YYYYMMDDhhmmss_OBSID_FILTER_L0_VER.fits，其中CHANNEL、TYPE、YYYYMMDD、hhmmss、OBSID、FILTER、L0和VER分别代表通道编号、目标类型、观测日期、观测时间、观测编号、滤光片编号、L0级数据和版本号。"
#     },
#     {
#         "content": "IFS模块的0级数据文件名中，CAMERA字段代表什么？",
#         "summary": "IFS模块的0级数据文件名中，CAMERA字段代表光谱仪编号，红端CCD为“R”，蓝端CCD为“B”。"
#     },
#     {
#         "content": "CPIC模块的可见光相机和红外相机在0级数据文件名中分别如何表示？",
#         "summary": "CPIC模块的0级数据文件名中，可见光相机和红外相机分别用“VIS”和“NIR”表示。"
#     },
#     {
#         "content": "HSTDM模块中，探测器的黑体校准数据在文件名中如何标识？",
#         "summary": "HSTDM模块中，探测器的黑体校准数据在文件名中通过TYPE2字段标识为“BLK”，如CSST_HSTDM_ONS_BLK_YYYYMMDDhhmmss_YYYYMMDDhhmmss_OBSID_MM-NNNN_L0_VER.fits，表示对目标源进行观测时的黑体校准数据。"
#     },
#     {
#         "content": "如果对象数据使用fpack工具压缩，文件后缀是什么？",
#         "summary": "如果对象数据使用fpack工具压缩，文件后缀应为.fits.fz。"
#     },
#     {
#         "content": "文件索引号是如何从文件名中计算得到的？",
#         "summary": "文件索引号通过计算文件名的SHA256散列值给出，取散列值的前128bit为文件索引号。"
#     },
#     {
#         "content": "FITS格式文件需要支持哪些主流读写软件？",
#         "summary": "FITS格式文件需要支持的主流读写软件至少应当包括astropy.io.fits和libcfitsio。"
#     },
#     {
#         "content": "MSC模块的光学数据文件对象包含多少个HDU？",
#         "summary": "MSC模块的光学数据文件对象包含两个HDU，其中一个是primary HDU，另一个是图像扩展（raw image）。"
#     },
#     {
#         "content": "MSC模块的primary HDU中主要包含哪些信息？",
#         "summary": "MSC模块的primary HDU主要包含望远镜的位置姿态信息。同一次观测所有波段测光和无缝光谱图像的global header内容基本一致。"
#     }
# ]
# ```
# File 'new_file.txt' has been created and written.
# new_txt_files/text_file4.txt
# text_content
#  快门读出等内容，image data 部分为从探测器读出后未经任何修改的0
# 级数据。主巡天相机和定标组件的image data 数据应该为一个2 维的
# datacube 矩阵，以探测器选型使用CCD 为例，如果按照计划的16 通道
# 读出，需要将16 通道数据按照读出先后次序，顺序排列为一个2 维矩
# 阵（如图7 所示）。
# 图6. CSST 主巡天光学相机0 级数据结构示意图
# 图7. CSST 主巡天0 级数据image data 结构示意图，其中数字表示不同的读出通
# 道，通道间的分隔用黑色边框表示。橙色为data 区域，蓝色为over (pre) scan 区
# 域，（0，0）在左上角。
# 15
# 红外数据文件对象接口如图8 所示：
# 文件对象包含两个HDU，其中primary HDU（图中的global header）
# 只包含望远镜的位置姿态信息。同一次观测所有波段测光和无缝光谱图
# 像global header 内容基本一致。在主巡天单次曝光150s 时间内，会多次
# 读出，产生多帧图像（最多可产生256 帧，其中每一帧累积前面的数
# 据），形成一个三维的datacube，存于图像扩展中（图中的raw image）。
# raw image 的header 包含探测器相关信息、WCS 相关数据、曝光相关信
# 息，image data 部分为从探测器读出后未经任何修改的0 级数据。
# 5.3.2.
# 多通道成像仪模块（MCI）
# 文件对象（不包含导星数据和工程信息数据）接口如图9 所示：
# 图8. CSST 主巡天红外相机0 级数据结构示意图
# 图9. MCI 0 级数据结构示意图
# 16
# 文件对象包含两个HDU，其中primary HDU（图中的global header）
# 只包含望远镜的位置姿态信息。同一次观测所有波段测光图像global
# header 内容基本一致。对象有一个图像扩展（图中的raw image），raw
# image 的header 包含CCD 相关信息、WCS 相关数据、快门读出等内容，
# image data 部分为从探测器读出后未经任何修改的0 级数据。MCI 和定标
# 组件的image data 数据应该为一个2 维的datacube 矩阵，以探测器选型使
# 用CCD 为例，需要按照通道号从小到大的顺序将16 通道数据从左到右
# 排列为一个二维矩阵（如图10 所示）。
# 5.3.3.
# 积分视场光谱仪模块（IFS）
# 文件对象（不包含导星数据和工程信息数据）接口如图11 所示：
# 图10. MCI 0 级数据image data 结构示意图，其中OS1-OS16 表示不同的读出通道，
# 16 个输出通道（OS1-OS16）中，每个通道输出各自物理区域（如上图）共计1499
# （列）×4936（行）（pixels），其中，1499=27（prescan）+1152（physical pixels）
# +320（virtual overscan），4936=4616（physical pixels）+320（virtual overscan）；一
# 帧0 级数据image data 输出像元尺寸：23984（列）×4936（行）（pixels）；（0，
# 0）在左上角。
# 图11. IFS 0 级数据结构示意图
# 17
# 文件对象包含两个HDU，其中primary HDU (图中的global header)只
# 包含望远镜的位置姿态信息。Raw image 的header 包含CCD 相关信息，
# image data 部分为从探测器读出后未经任何修改的0 级数据。IFS 的
# image data 数据应该为一个3 维的datacube 矩阵，以探测器选型使用CCD
# 为例，如果按照计划的4 通道读出，需要将4 通道数据按照读出先后次
# 序，顺序排列为一个2 维矩阵, 在此2 维矩阵的基础上，第三维为在相同
# 曝光、指向、跟踪、obsid 下，一次采集的帧数n（如图12 所示）。
# 图12. IFS 0 级数据image data 结构示意图，其中数字表示不同的读出通道，通道间的
# 分隔用黑色边框表示。橙色为data 区域，蓝色为over (pre) scan 区域，（0，0）在左上
# 角。1, 2, 3, 4 表示同一个探测器不同的读出通道（门）。共有4 个输出通道, 每个通道
# 都含有50 列prescan, 320 行及320 列overscan。其中，蓝端探测器CCD 每个读出通道
# （门）的物理区域如上图所示，1344（行）* 2418（列）（pixels），一帧紫外图像数
# 据，需要传输1344 次。其中，1344 = 1024（physical pixels）+ 320（virtual overscan）;
# 18
# 5.3.4.
# 系外行星成像星冕仪（CPIC）
# 文件对象接口如图13 所示：
# 文件对象包含若干个HDU，其中primary HDU（图中的global
# header）只包含望远镜的位置姿态信息。其余HDU 为图像HDU（图中
# 的raw image），raw image 的header 包含CCD 相关信息、WCS 相关
# 数据、曝光相关信息，image data 部分为从探测器读出后未经任何修改
# 的0 级图像数据。星冕仪模块可见光图像数据像素为1080*1050，红外
# 为640*512。数据类型为无符号16 位整形，如果相机读出的数据不足
# 2418 = 50（prescan）+ 2048（physical pixels）+ 320（virtual overscan）；一帧0 级数
# 据image data 输出像元尺寸：1344（行）× 9672（列）（pixels）。红端探测器CCD
# 每个读出通道（门）的物理区域如上图所示，1856（行）* 3442（列）（pixels），一
# 帧可见光图像数据，需要传输1856 次。其中，1856 = 1536（physical pixels）+320
# （virtual overscan ）；3442 = 50 （prescan ）+3072（physical pixels ）+320 （virtual
# overscan）；一帧0 级数据image data 输出像元尺寸：1856（行）×13768（列）
# （pixels）。
# 图13. CPIC 0 级数据结构示意图
# 19
# 16 位，在高位进行补零。
# 5.3.5.
# 高灵敏度太赫兹模块（HSTDM）
# 文件对象接口如图14 所示：
# 太赫兹模块0 级数据按照建议文件夹自动存储后，由数据库自动检
# 索入库。文件对象包含两个HDU，其中primary HDU（图中的global
# header）只包含望远镜的位置姿态信息。对象有一个图像扩展（图中的
# raw image），raw image 的header 包含接收机相关信息，image data 部分
# 为从探测器读出后未经任何修改的0 级数据，为二进制文件，数据的状
# 态字为ASCII 码固定格式。
# 5.4. 接口名称和项目识别号
# 5.4.1.
# 接口需求
# 数据对象在模块间传递应同时允许文件传递和数据流传递。
# 5.4.2.
# 数据元素
# 对象头关键字见表3（global header），表4 和表5（主巡天模块raw
# image 中header），表6（MCI 模块raw image 中header），表7（IFS 模
# 图14.HSTDM 0 级数据结构示意图
# 20
# 块raw image 中header），表8（星冕仪模块raw image 中header），表9
# （太赫兹模块raw image 中header）。其中：
# 第一列keyword 为元素唯一识别号，也是FITS 格式头文件的关键字，
# 关键字由大写字母和数字组成，其中数字不可作为关键字的首字符，最
# 多8 个字符。
# 第二列给出元素可能的值。
# 第三列为元素的描述，也是FITS 头文件每个关键字的注释。元素的
# 物理单位也包含在第三列的注释中。
# 第三列为元素的数据类型，其中bool 表示为布尔型，可以是T 或F；
# int 是整型，float 是浮点型，strxx，其中xx 表示字符串的最大长度。
# 21
# 表3.全局头文件关键字
# GLOBAL HEADER KEYWORDS
# keyword
# example
# comment
# dtype
# GENERAL KEYWORDS
# SIMPLE
# TRUE
# conforms to FITS standard
# bool
# BITPIX
# 8
# array data type
# int
# NAXIS
# 0
# number of array dimensions
# int
# EXTEND
# TRUE
# bool
# NEXTEND
# 1
# number of array dimensions
# int
# DATE
# 2024-08-
# 17T06:05:12.0
# written date (yyyy-mm-ddThh:mm:ss.s)
# str21
# FILENAME
# CSST_MSC_
# MS_SCI_2024
# 0817060512_2
# 024081706074
# 2_1016010000
# 0_09_L0_V01
# str
# FILETYPE
# SCI
# observation type
# str
# TELESCOP
# CSST
# telescope name
# str4
# INSTRUME
# MSC
# instrument name
# str3
# RADECSYS
# ICRS
# coordinate system of the object
# str
# EQUINOX
# 2000.0
# float
# FITSSWV
# 2.1.0_202312
# 08_wcl-5
# FITS creating software version
# str
# COMMENT
# ==========
# str72
# 22
# ===========
# ===========
# ===========
# ===========
# ===========
# =======
# OBJECT INFORMATION
# OBJECT
# 60000000
# object name
# str
# TARGET
# 161953.0+39
# 5345
# target name (hhmmss.s+ddmmss)
# str15
# OBSID
# 10160100066
# observation ID
# str
# RA_OBJ
# 244.972773
# object RA (deg)
# float
# DEC_OBJ
# 39.895901
# object Dec (deg)
# float
# TELESCOPE INFORMATION
# REFFRAME
# CSSTGSC-
# 1.0
# guiding catalog version
# str
# DATE-OBS
# 2024-08-
# 17T06:05:12.0
# observation
# date
# (yyyy-mm-
# ddThh:mm:ss.s)
# str21
# SATESWV
# 1
# satellite software version
# str
# EXPSTART
# 60539.25361
# exposure start time (MJD)
# float
# CABSTART
# 60539.25361
# first cabin time after exposure start
# (MJD)
# float
# SUNANGL0
# 50.0
# angle between the Sun and opt axis at
# CABSTART
# float
# 23
# MOONANG0
# 30.0
# angle between the Moon and opt axis at
# CABSTART
# float
# TEL_ALT0
# 20.0
# angle between opt axis and Elimb at
# CABSTART
# float
# POS_ANG0
# 20.0
# angle between y axis and North Pole at
# CABSTART
# float
# POSI0_X
# -2218.3663
# orbital position in X at CABSTART
# (km)
# float
# POSI0_Y
# -5817.8559
# orbital position in Y at CABSTART
# (km)
# float
# POSI0_Z
# 2597.9467
# orbital position in Z at CABSTART
# (km)
# float
# VELO0_X
# 5.058199026
# orbital velocity in X at CABSTART
# (km/s)
# float
# VELO0_Y
# -3.858187999
# orbital velocity in Y at CABSTART
# (km/s)
# float
# VELO0_Z
# -4.322908628
# orbital velocity in Z at CABSTART
# (km/s)
# float
# EULER0_1
# 0.0
# Euler angle 1 at CABSTART (deg)
# float
# EULER0_2
# 0.0
# Euler angle 2 at CABSTART (deg)
# float
# EULER0_3
# 0.0
# Euler angle 3 at CABSTART (deg)
# float
# RA_PNT0
# 244.972773
# pointing RA at CABSTART (deg)
# float
# DEC_PNT0
# 39.895901
# pointing Dec at CABSTART (deg)
# float
# EXPEND
# 60539.25535
# exposure end time (MJD)
# float
# CABEND
# 60539.25535
# first
# cabin
# time
# after
# exposure
# end
# float
# 24
# (MJD)
# SUNANGL1
# 50.0
# angle between the Sun and opt axis at
# CABEND
# float
# MOONANG1
# 30.0
# angle between the Moon and opt axis at
# CABEND
# float
# TEL_ALT1
# 20.0
# angle between opt axis and Elimb at
# CABEND
# float
# POS_ANG1
# 20.0
# angle between y axis and North Pole at
# CABEND
# float
# POSI1_X
# 0.0
# orbital position in X at CABEND (km)
# float
# POSI1_Y
# 0.0
# orbital position in Y at CABEND (km)
# float
# POSI1_Z
# 0.0
# orbital position in Z at CABEND (km)
# float
# VELO1_X
# 0.0
# orbital velocity in X at CABEND (km/s)
# float
# VELO1_Y
# 0.0
# orbital velocity in Y at CABEND (km/s)
# float
# VELO1_Z
# 0.0
# orbital velocity in Z at CABEND (km/s)
# float
# EULER1_1
# 0.0
# Euler angle 1 at CABEND (deg)
# float
# EULER1_2
# 0.0
# Euler angle 2 at CABEND (deg)
# float
# EULER1_3
# 0.0
# Euler angle 3 at CABEND (deg)
# float
# RA_PNT1
# 244.972773
# pointing RA at CABEND (deg)
# float
# DEC_PNT1
# 39.895901
# pointing Dec at CABEND (deg)
# float
# EPOCH
# 2024.6
# equinox of pointing RA and Dec
# float
# 25
# 表4. 0 级数据头文件关键字（MSC_MS）
# EXPTIME
# 150.0
# exposure time (s)
# float
# VERIFICATION INFORMATION
# CHECKSUM
# QAWaQ8TX
# QATaQ7TU
# HDU
# checksum
# updated
# 2024-03-
# 07T08:52:11
# str
# DATASUM
# 0
# data unit checksum updated 2024-03-
# 07T08:52:11
# str
# RAW EXTENSION HEADER KEYWORDS
# keyword
# example
# comment
# dtype
# GENERAL KEYWORDS
# XTENSION
# IMAGE
# image extension
# str
# BITPIX
# 16
# array data type
# int
# NAXIS
# 2
# number of array dimensions
# int
# 耗时 16.78788471221924
# {'id': 'as-j0x18qda62', 'object': 'chat.completion', 'created': 1722394680, 'result': '1. 主巡天相机和定标组件的image data数据是什么形式的矩阵？\n2. 在CSST主巡天红外相机中，0级数据如何组织成一个三维的datacube？\n3. MCI 0级数据image data中的数据是如何按通道排列的？\n4. IFS的image data数据是如何从4通道数据组织成一个三维datacube的？\n5. CPIC模块的可见光和红外图像的像素尺寸分别是多少？\n6. HSTDM模块的0级数据image data是什么类型的文件？\n7. 全局头文件中的关键字`BITPIX`代表什么？\n8. 在全局头文件中，`RA_OBJ`和`DEC_OBJ`分别表示什么？\n9. `EXPTIME`关键字在MSC_MS 0级数据头文件中表示什么？\n10. RAW EXTENSION HEADER中的`XTENSION`关键字的作用是什么？', 'is_truncated': False, 'need_clear_history': False, 'finish_reason': 'normal', 'usage': {'prompt_tokens': 3576, 'completion_tokens': 182, 'total_tokens': 3758}}
# question_text
#  1. 主巡天相机和定标组件的image data数据是什么形式的矩阵？
# 2. 在CSST主巡天红外相机中，0级数据如何组织成一个三维的datacube？
# 3. MCI 0级数据image data中的数据是如何按通道排列的？
# 4. IFS的image data数据是如何从4通道数据组织成一个三维datacube的？
# 5. CPIC模块的可见光和红外图像的像素尺寸分别是多少？
# 6. HSTDM模块的0级数据image data是什么类型的文件？
# 7. 全局头文件中的关键字`BITPIX`代表什么？
# 8. 在全局头文件中，`RA_OBJ`和`DEC_OBJ`分别表示什么？
# 9. `EXPTIME`关键字在MSC_MS 0级数据头文件中表示什么？
# 10. RAW EXTENSION HEADER中的`XTENSION`关键字的作用是什么？
# 耗时 72.54374241828918
# {'id': 'as-rud4g5sgnq', 'object': 'chat.completion', 'created': 1722394752, 'result': '```json\n[\n    {\n        "content": "主巡天相机和定标组件的image data数据是什么形式的矩阵？",\n        "summary": "主巡天相机和定标组件的image data数据应该为一个2维的datacube矩阵，以探测器选型使用CCD为例，如果按照计划的16通道读出，需要将16通道数据按照读出先后次序，顺序排列为一个2维矩阵。"\n    },\n    {\n        "content": "在CSST主巡天红外相机中，0级数据如何组织成一个三维的datacube？",\n        "summary": "在主巡天单次曝光150s时间内，CSST主巡天红外相机会多次读出，产生多帧图像（最多可产生256帧，其中每一帧累积前面的数据），形成一个三维的datacube，存于图像扩展中。"\n    },\n    {\n        "content": "MCI 0级数据image data中的数据是如何按通道排列的？",\n        "summary": "MCI 0级数据的image data部分，以探测器选型使用CCD为例，需要按照通道号从小到大的顺序将16通道数据从左到右排列为一个二维矩阵。"\n    },\n    {\n        "content": "IFS的image data数据是如何从4通道数据组织成一个三维datacube的？",\n        "summary": "IFS的image data数据应该为一个3维的datacube矩阵，以探测器选型使用CCD为例，需要将4通道数据按照读出先后次序，顺序排列为一个2维矩阵，在此基础上，第三维为在相同曝光、指向、跟踪、obsid下，一次采集的帧数n。"\n    },\n    {\n        "content": "CPIC模块的可见光和红外图像的像素尺寸分别是多少？",\n        "summary": "CPIC模块的可见光图像数据像素为1080*1050，红外图像数据像素为640*512。"\n    },\n    {\n        "content": "HSTDM模块的0级数据image data是什么类型的文件？",\n        "summary": "HSTDM模块的0级数据image data是二进制文件，数据的状态字为ASCII码固定格式。"\n    },\n    {\n        "content": "全局头文件中的关键字`BITPIX`代表什么？",\n        "summary": "全局头文件中的`BITPIX`关键字表示数组数据类型，比如8代表8位整数，16代表16位整数等。"\n    },\n    {\n        "content": "在全局头文件中，`RA_OBJ`和`DEC_OBJ`分别表示什么？",\n        "summary": "`RA_OBJ`表示观测目标的赤经（RA），单位为度；`DEC_OBJ`表示观测目标的赤纬（Dec），单位为度。"\n    },\n    {\n        "content": "`EXPTIME`关键字在MSC_MS 0级数据头文件中表示什么？",\n        "summary": "`EXPTIME`关键字在MSC_MS 0级数据头文件中表示曝光时间，单位为秒。"\n    },\n    {\n        "content": "RAW EXTENSION HEADER中的`XTENSION`关键字的作用是什么？",\n        "summary": "RAW EXTENSION HEADER中的`XTENSION`关键字表示这是一个图像扩展，即表明该部分数据包含的是图像信息。"\n    }\n]\n```', 'is_truncated': False, 'need_clear_history': False, 'finish_reason': 'normal', 'usage': {'prompt_tokens': 3832, 'completion_tokens': 705, 'total_tokens': 4537}}
# qa_text
#  ```json
# [
#     {
#         "content": "主巡天相机和定标组件的image data数据是什么形式的矩阵？",
#         "summary": "主巡天相机和定标组件的image data数据应该为一个2维的datacube矩阵，以探测器选型使用CCD为例，如果按照计划的16通道读出，需要将16通道数据按照读出先后次序，顺序排列为一个2维矩阵。"
#     },
#     {
#         "content": "在CSST主巡天红外相机中，0级数据如何组织成一个三维的datacube？",
#         "summary": "在主巡天单次曝光150s时间内，CSST主巡天红外相机会多次读出，产生多帧图像（最多可产生256帧，其中每一帧累积前面的数据），形成一个三维的datacube，存于图像扩展中。"
#     },
#     {
#         "content": "MCI 0级数据image data中的数据是如何按通道排列的？",
#         "summary": "MCI 0级数据的image data部分，以探测器选型使用CCD为例，需要按照通道号从小到大的顺序将16通道数据从左到右排列为一个二维矩阵。"
#     },
#     {
#         "content": "IFS的image data数据是如何从4通道数据组织成一个三维datacube的？",
#         "summary": "IFS的image data数据应该为一个3维的datacube矩阵，以探测器选型使用CCD为例，需要将4通道数据按照读出先后次序，顺序排列为一个2维矩阵，在此基础上，第三维为在相同曝光、指向、跟踪、obsid下，一次采集的帧数n。"
#     },
#     {
#         "content": "CPIC模块的可见光和红外图像的像素尺寸分别是多少？",
#         "summary": "CPIC模块的可见光图像数据像素为1080*1050，红外图像数据像素为640*512。"
#     },
#     {
#         "content": "HSTDM模块的0级数据image data是什么类型的文件？",
#         "summary": "HSTDM模块的0级数据image data是二进制文件，数据的状态字为ASCII码固定格式。"
#     },
#     {
#         "content": "全局头文件中的关键字`BITPIX`代表什么？",
#         "summary": "全局头文件中的`BITPIX`关键字表示数组数据类型，比如8代表8位整数，16代表16位整数等。"
#     },
#     {
#         "content": "在全局头文件中，`RA_OBJ`和`DEC_OBJ`分别表示什么？",
#         "summary": "`RA_OBJ`表示观测目标的赤经（RA），单位为度；`DEC_OBJ`表示观测目标的赤纬（Dec），单位为度。"
#     },
#     {
#         "content": "`EXPTIME`关键字在MSC_MS 0级数据头文件中表示什么？",
#         "summary": "`EXPTIME`关键字在MSC_MS 0级数据头文件中表示曝光时间，单位为秒。"
#     },
#     {
#         "content": "RAW EXTENSION HEADER中的`XTENSION`关键字的作用是什么？",
#         "summary": "RAW EXTENSION HEADER中的`XTENSION`关键字表示这是一个图像扩展，即表明该部分数据包含的是图像信息。"
#     }
# ]
# ```
# File 'new_file.txt' has been created and written.
# new_txt_files/text_file5.txt
# text_content
#  NAXIS1
# 20000
# int
# NAXIS2
# 4700
# int
# PCOUNT
# 0
# number of parameters
# int
# GCOUNT
# 1
# number of groups
# int
# BSCALE
# 1
# int
# BZERO
# 32768
# int
# EXTNAME
# IMAGE
# extension name
# str
# EXTVER
# 1
# extension version number
# int
# BUNIT
# ADU
# physical unit of array values
# str
# COMMENT
# =========
# str72
# 26
# ===========
# ===========
# ===========
# ===========
# ===========
# ========
# DETECTOR INFORMATION
# CAMERA
# MS
# camera of main survey
# str2
# DETSN
# 12345678
# detector serial number
# str
# DETNAME
# CCD
# detector type
# str
# DETTEMP1
# 173
# detector temperature at EXPSTART (K)
# float
# DETTEMP2
# 173
# detector temperature at EXPEND (K)
# float
# DETTEMP3
# 173
# detector temperature at ROTIME1 (K)
# float
# DETSIZE
# 20000x4700
# detector size
# str
# DATASECT
# 9216x9232
# data section
# str
# PIXSCAL1
# 0.074
# pixel scale for axis 1 (arcsec/pixel)
# float
# PIXSCAL2
# 0.074
# pixel scale for axis 2 (arcsec/pixel)
# float
# PIXSIZE1
# 10
# pixel size for axis 1 (micron)
# int
# PIXSIZE2
# 10
# pixel size for axis 2 (micron)
# int
# CHIPID
# 9
# chip ID
# str2
# CHIPLABL
# r-1
# chip label
# str
# FILTER
# r
# filter name
# str
# NCHANNEL
# 16
# number of readout channels
# int
# PSCAN1
# 27
# horizontal prescan width, per readout
# channel
# int
# 27
# PSCAN2
# 8
# vertical
# prescan
# width,
# per
# readout
# channel
# int
# OSCAN1
# 16
# horizontal overscan width, per readout
# channel
# int
# OSCAN2
# 16
# vertical overscan width, per readout
# channel
# int
# WORLD COORDINATE SYSTEM INFORMATION
# WCSAXES
# 2
# number of WCS axes
# int
# CRPIX1
# 4600.69465
# x-coordinate of reference pixel
# float
# CRPIX2
# 4604.383757
# y-coordinate of reference pixel
# float
# CRVAL1
# 244.5872723
# value of reference pixel on axis 1
# float
# CRVAL2
# 39.68195466
# value of reference pixel on axis 2
# float
# CTYPE1
# RA---TAN
# type of RA WCS projection
# str8
# CTYPE2
# DEC--TAN
# type of Dec WCS projection
# str8
# CD1_1
# -6.81E-06
# transformation matrix element (deg/pix)
# float
# CD1_2
# -1.94E-05
# transformation matrix element (deg/pix)
# float
# CD2_1
# -1.94E-05
# transformation matrix element (deg/pix)
# float
# CD2_2
# 6.81E-06
# transformation matrix element (deg/pix)
# float
# READOUT INFORMATION
# GAINLVL
# 1
# gain level
# str2
# 28
# GAIN01
# 1.089977689
# gain (e-/ADU, channel 01)
# float
# GAIN02
# 1.09917562
# gain (e-/ADU, channel 02)
# float
# GAIN03
# 1.107649165
# gain (e-/ADU, channel 03)
# float
# GAIN04
# 1.121722215
# gain (e-/ADU, channel 04)
# float
# GAIN05
# 1.081220798
# gain (e-/ADU, channel 05)
# float
# GAIN06
# 1.094562729
# gain (e-/ADU, channel 06)
# float
# GAIN07
# 1.111430472
# gain (e-/ADU, channel 07)
# float
# GAIN08
# 1.105606424
# gain (e-/ADU, channel 08)
# float
# GAIN09
# 1.10187497
# gain (e-/ADU, channel 09)
# float
# GAIN10
# 1.085064047
# gain (e-/ADU, channel 10)
# float
# GAIN11
# 1.122187725
# gain (e-/ADU, channel 11)
# float
# GAIN12
# 1.114934178
# gain (e-/ADU, channel 12)
# float
# GAIN13
# 1.119336505
# gain (e-/ADU, channel 13)
# float
# GAIN14
# 1.09303619
# gain (e-/ADU, channel 14)
# float
# GAIN15
# 1.084334798
# gain (e-/ADU, channel 15)
# float
# GAIN16
# 1.090894538
# gain (e-/ADU, channel 16)
# float
# RON01
# 5.0
# readout noise (e-, channel 01)
# float
# RON02
# 5.0
# readout noise (e-, channel 02)
# float
# RON03
# 5.0
# readout noise (e-, channel 03)
# float
# RON04
# 5.0
# readout noise (e-, channel 04)
# float
# RON05
# 5.0
# readout noise (e-, channel 05)
# float
# RON06
# 5.0
# readout noise (e-, channel 06)
# float
# RON07
# 5.0
# readout noise (e-, channel 07)
# float
# RON08
# 5.0
# readout noise (e-, channel 08)
# float
# RON09
# 5.0
# readout noise (e-, channel 09)
# float
# 29
# RON10
# 5.0
# readout noise (e-, channel 10)
# float
# RON11
# 5.0
# readout noise (e-, channel 11)
# float
# RON12
# 5.0
# readout noise (e-, channel 12)
# float
# RON13
# 5.0
# readout noise (e-, channel 13)
# float
# RON14
# 5.0
# readout noise (e-, channel 14)
# float
# RON15
# 5.0
# readout noise (e-, channel 15)
# float
# RON16
# 5.0
# readout noise (e-, channel 16)
# float
# ROTIME0
# 2024-08-
# 17T06:07:42.1
# readout start time (UTC)
# str21
# ROTIME1
# 2024-08-
# 17T06:08:22.1
# readout end time (UTC)
# str21
# ROSPEED
# 10.0
# readout speed (MHz)
# float
# EXPTIME
# 150.0
# exposure time (s)
# float
# DARKTIME
# 152.0
# dark current time (s)
# float
# SHUTTER INFORMATION
# SHTSTAT
# TRUE
# shutter status, T=open, F=close
# bool
# SHTOPEN0
# 2024-08-
# 17T06:07:42.1
# shutter open time (start, UTC)
# str21
# SHTOPEN1
# 2024-08-
# 17T06:07:42.1
# shutter open time (end, UTC)
# str21
# SHTCLOS0
# 2024-08-
# 17T06:07:42.1
# shutter close time (start, UTC)
# str21
# SHTCLOS1
# 2024-08-
# 17T06:07:42.1
# shutter close time (end, UTC)
# str21
# LED INFORMATION
# 30
# LEDFLAG
# main
# main/backup LED
# str
# LEDSTAT
# 00000000000
# 000
# LED status
# str14
# LEDT01
# 0.0
# LED01 flash time (ms)
# float
# LEDT02
# 0.0
# LED02 flash time (ms)
# float
# LEDT03
# 0.0
# LED03 flash time (ms)
# float
# LEDT04
# 0.0
# LED04 flash time (ms)
# float
# LEDT05
# 0.0
# LED05 flash time (ms)
# float
# LEDT06
# 0.0
# LED06 flash time (ms)
# float
# LEDT07
# 0.0
# LED07 flash time (ms)
# float
# LEDT08
# 0.0
# LED08 flash time (ms)
# float
# LEDT09
# 0.0
# LED09 flash time (ms)
# float
# LEDT10
# 0.0
# LED10 flash time (ms)
# float
# LEDT11
# 0.0
# LED11 flash time (ms)
# float
# LEDT12
# 0.0
# LED12 flash time (ms)
# float
# LEDT13
# 0.0
# LED13 flash time (ms)
# float
# LEDT14
# 0.0
# LED14 flash time (ms)
# float
# LEDTEMP
# 173.0
# LED temperature (K)
# float
# VERIFICATION INFORMATION
# CHECKSUM
# 5aDaAZAV8
# aAaAWAU
# HDU checksum
# str
# DATASUM
# 3747953988
# data unit checksum
# str
# 31
# 表5. 0 级数据头文件关键字（MSC_IR）
# RAW EXTENSION HEADER KEYWORDS
# keyword
# example
# comment
# dtype
# GENERAL KEYWORDS
# XTENSION
# IMAGE
# image extension
# str
# BITPIX
# 16
# array data type
# int
# NAXIS
# 3
# number of array dimensions
# int
# NAXIS1
# 640
# int
# NAXIS2
# 512
# int
# NAXIS3
# int
# BSCALE
# 1
# int
# BZERO
# 32768
# int
# EXTNAME
# IMAGE
# extension name
# str
# EXTVER
# 1
# extension version number
# int
# BUNIT
# ADU
# physical unit of array values
# str
# COMMENT
# ========
# =========
# =========
# =========
# =========
# =========
# =========
# =========
# =
# str72
# DETECTOR INFORMATION
# 32
# CAMERA
# IR
# camera of main survey
# str2
# DETSN
# 12345678
# detector serial number
# str
# DETNAME
# detector type
# str
# DETTEMP1
# 173
# detector temperature at EXPSTART (K)
# float
# DETTEMP2
# 173
# detector temperature at EXPEND (K)
# float
# DETTEMP3
# 173
# detector temperature at READT1 (K)
# float
# DEWTEMP
# dewer temperature (K)
# float
# DETSIZE
# 640x512
# detector size
# str
# DATASECT
# 640x512
# data section
# str
# PIXSCAL1
# pixel scale for axis 1 (arcsec/pixel)
# float
# PIXSCAL2
# pixel scale for axis 2 (arcsec/pixel)
# float
# PIXSIZE1
# pixel size for axis 1 (micron)
# int
# PIXSIZE2
# pixel size for axis 2 (micron)
# int
# CHIPID
# 11
# chip ID
# str2
# CHIPLABL
# ƴ'-1
# chip label
# str
# FILTER
# ƴ'
# filter name
# str
# NCHANNEL
# 1
# number of readout channels
# int
# WORLD COORDINATE SYSTEM INFORMATION
# WCSAXES
# 2
# number of WCS axes
# int
# CRPIX1
# 4600.69465
# x-coordinate of reference pixel
# float
# CRPIX2
# 4604.383757
# y-coordinate of reference pixel
# float
# CRVAL1
# 244.5872723
# value of reference pixel on axis 1
# float
# CRVAL2
# 39.68195466
# value of reference pixel on axis 2
# float
# 33
# 表6. 0 级数据头文件关键字（MCI）
# CTYPE1
# RA---TAN
# type of RA WCS projection
# str8
# CTYPE2
# DEC--TAN
# type of Dec WCS projection
# str8
# CD1_1
# -6.81E-06
# transformation matrix element (deg/pix)
# float
# CD1_2
# -1.94E-05
# transformation matrix element (deg/pix)
# float
# CD2_1
# -1.94E-05
# transformation matrix element (deg/pix)
# float
# CD2_2
# 6.81E-06
# transformation matrix element (deg/pix)
# float
# READOUT INFORMATION
# IMGNUM
# image number
# int
# EXPTIR
# IR exposure time between two images
# float
# GAINIR
# IR gain
# float
# RONIR
# IR readout noise
# float
# ROSPDIR
# IR readout speed (MHz)
# float
# VERIFICATION INFORMATION
# CHECKSUM
# 5aDaAZA
# V8aAaAWA
# U
# HDU checksum
# str
# DATASUM
# 3747953988
# data unit checksum
# str
# 34
# RAW EXTENSION HEADER KEYWORDS
# keyword
# example
# comment
# dtype
# GENERAL KEYWORDS
# XTENSION
# IMAGE
# extension type
# str5
# BITPIX
# 16
# array data type
# int
# NAXIS
# 2
# number of array dimensions
# int
# NAXIS1
# 23984
# int
# NAXIS2
# 4936
# int
# PCOUNT
# 0
# number of parameters
# int
# GCOUNT
# 1
# number of groups
# int
# BSCALE
# 1
# int
# BZERO
# 32768
# int
# EXTNAME
# SCI
# str3
# EXTVER
# 1
# int
# BUNIT
# ADU
# physical unit of array values
# str
# COMMENT
# ========
# =========
# =========
# =========
# =========
# =========
# =========
# str72
# 35
# =========
# =
# FILE INFORMATION
# DATE
# 2023-12-
# 18T17:01:40.
# 1
# written date (yyyy-mm-ddThh:mm:ss.s)
# str21
# FILENAME
# CSST_MCI
# _C1_EXDF_
# 20231218141
# 341_2023121
# 8141841_201
# 00000001_07
# _L0_V01
# str
# FILETYPE
# EXDF
# observation type
# str
# RADECSYS
# ICRS
# coordinate system of the object
# str
# EQUINOX
# 2000.1
# float
# FITSSWV
# 4.2.1
# FITS creating software version
# str
# INSTRUMENT STATUS AND OBJECT INFORMATION
# TELESCOP
# CSST
# telescope name
# str4
# INSTRUME
# MCI
# instrument name
# str3
# CHANNEL
# C1
# channel number
# str
# FILTERNO
# 07
# filter number
# str
# DIFFUSER
# TRUE
# insert diffuser status for flat calibration
# bool
# 36
# FLAMP
# 1
# status of flat lamp
# int
# MCISTAT
# 11111
# MCI components status parameter
# int
# OBJECT
# MCI_obj
# object name
# str
# TARGET
# 074443.0+
# 392523
# target name (hhmmss.s+ddmmss)
# str15
# OBSID
# 20100000066
# observation ID
# str
# RA_OBJ
# 116.1808154
# object RA (deg)
# float
# DEC_OBJ
# 39.42316681
# object Dec (deg)
# float
# DATE-OBS
# 2023-12-18
# T14:13:41.1
# observation
# date
# (yyyy-mm-
# ddThh:mm:ss.s)
# str21
# DETECTOR AND FILTER INFORMATION
# FILTER
# u
# filter band
# str
# DETSN
# E2V-CCD-
# 000-0000000
# detector serial number
# str
# DETNAME
# uv
# detector name
# str
# DETTEMP0
# 0.1
# detector temperature at EXPSTART (K)
# float
# DETTEMP1
# 0.1
# ...
# 13
# 观测效率校准（CAL_EFF）
# 116
# 0 级数据定义第三版更改条目说明
# 更改前
# 更改后
# 文档名称：CSST 科学数据处理系统输入
# 数据需求和0 级数据结构设计说明
# 文档名称：CSST 科学数据处理系统0 级
# 数据输入需求和数据结构设计说明
# obsid，4byte，3bit 表示后端模块，4bit 表
# 示观测类型，25bit 表示曝光编号
# obsid，4byte，3bit 表示后端模块，5bit 表
# 示观测类型，24bit 表示曝光编号。各模
# 块观测类型编号进行了更新
# 第5.4.2 章，数据元素描述：对象头关键
# 字见表2（global header），表3（主巡天
# 模块raw image 中header），表4（MCI
# 模块raw image 中header），表5（IFS 模
# 块raw image 中header），表6（星冕仪
# 模块raw image 中header），表7（太赫
# 兹模块raw image 中header）。其中：
# 第一列keyword 为元素唯一识别号，也是
# FITS 格式头文件的关键字，关键字由大
# 写字母和数字组成，其中数字不可作为关
# 键字的首字符，最多8 个字符。
# 第二列为元素的描述，也是FITS 头文件
# 每个关键字的注释。元素的物理单位也包
# 含在第二列的注释中。
# 第三列为元素的格式，其中L1（BOOL）
# 表示为布尔型，可以是T 或F ；I2
# （SMALLINT；INT16）是16bit 整型，I4
# （INT ；INT32 ）是32bit 整型；R4
# （FLOAT ）为单精度浮点型，R8
# 第5.4.2 章，数据元素描述：对象头关键
# 字见表3（global header），表4 和表5
# （主巡天模块raw image 中header），表
# 6（MCI 模块raw image 中header），表7
# （IFS 模块raw image 中header），表8
# （星冕仪模块raw image 中header），表
# 9（太赫兹模块raw image 中header）。其
# 中：
# 第一列keyword 为元素唯一识别号，也是
# FITS 格式头文件的关键字，关键字由大
# 写字母和数字组成，其中数字不可作为关
# 键字的首字符，最多8 个字符。
# 第二列给出元素可能的值。
# 第三列为元素的描述，也是FITS 头文件
# 每个关键字的注释。元素的物理单位也包
# 含在第三列的注释中。
# 第三列为元素的数据类型，其中bool 表
# 示为布尔型，可以是T 或F；in 是整型，
# float 是浮点型，strxx，其中xx 表示字符
# 117
# （DOUBLE ）为双精度浮点型；Cxx
# （CHAR）为字符串，其中xx 表示字符
# 串的最大长度。
# 第四列Remark 给出元素可能的值。
# 第五列为参数写入方式的标定：a. 观测
# ／定标数据；b. 设定值（比如平场灯档
# 位）；c. 写定值；d. 工程遥测；e. 地面
# 解算（括号中为数据库对应数据格式的约
# 定数字列类型）
# 串的最大长度。
# 第5.4.2 章，表3 （全局关键字），4
# （MSC_MS ），5 （MSC_IR ），6
# （MCI ），7 （IFS ），8 （CPIC ），9
# （HSTDM）按上述描述进行了更新。表
# 格中关键字comment 小写，关键字间的
# comment 大写。
# 第5.4.2 章，表3，删除关键字GROUPS
# 第5.4.2 章，表3，关键字FITSCREA
# 第5.4.2 章，表3，关键字FITSSWV
# 第5.4.2 章，表3 ，关键字OBJ_RA ，
# OBJ_DEC
# 第5.4.2 章，表3 ，关键字RA_OBJ ，
# DEC_OBJ
# MSC
# 第5.2.1 章，TYPE 描述：TYPE 表示目标
# 类型，4 位字符串，有6 种类型...1 种科
# 学观测模式SCIE（巡天观测）
# 第5.2.1 章，TYPE 描述：TYPE 表示目标
# 类型，共有6 种类型...1 种科学观测模式
# SCI（巡天观测）
# 第5.2.1 章，文件名举例如下：
# CSST_MSC_MS_SCIE_20240101120000_2
# 0240101120230_10100000012_10_L0_V01.
# 第5.2.1 章，文件名举例如下：
# CSST_MSC_MS_SCI_20240101120000_20
# 240101120230_10100000012_10_L0_V01.fi
# 118
# fits
# ts
# 第5.2.1 章，文件夹描述：ExpID 表示曝
# 光编号
# 第5.2.1 章，文件夹描述：OBSID 表示观
# 测编号
# 第5.2.1 章，示例文件名（包括路径）：
# CSST_L0/MSC/SCI/60310/100000012/M
# S/CSST_MSC_MS_SCIE_20240101120000
# _20240101120230_10100000012_10_L0_V
# 01.fits
# 第5.2.1 章，示例文件名（包括路径）：
# CSST_L0/MSC/SCI/60310/10100000012/
# MS/CSST_MSC_MS_SCI_20240101120000
# _20240101120230_10100000012_10_L0_V
# 01.fits
# 第5.2.1 章，图1，ExpID
# 第5.2.1 章，图1，OBSID
# 第5.4.2 章，表4，关键字CHIPLAB
# 第5.4.2 章，表4，关键字CHIPLABL
# 第5.4.2 章，表4，关键字NCHAN
# 第5.4.2 章，表4，关键字NCHANNAL
# 第5.4.2 章，表4，删除关键字OTHERS
# 第5.4.2 章，表4 ，关键字READT0 ，
# READT1
# 第5.4.2 章，表4，关键字ROTIME0，
# ROTIME1
# 第5.4.2 章，表4，删除关键字LEDEXPT
# 第5.4.2 章，表4，增加关键字LEDT01，
# LEDT02...LEDT14
# 第5.4.2 章，表5，增加关键字NAXIS3
# 第5.4.2 章，表5 ，删除关键字
# PIXSCAL，PIXSIZE
# 第5.4.2 章，表5 ，增加关键字
# PIXSCAL1 ，PIXSCAL2 ，PIXSIZE1 ，
# PIXSIZE2
# 第5.4.2 章，表5，关键字CHIPLAB
# 第5.4.2 章，表5，关键字CHIPLABL
# 第5.4.2 章，表5，关键字NCHAN
# 第5.4.2 章，表5，关键字NCHANNAL
# 第5.4.2 章，表5，删除关键字others
# 119
# MCI
# 第5.2.2 章，TYPE 描述：TYPE 表示目标
# 类型，4 位字符串，有13 种类型，包括
# 7 种内部定标模式BIAS（本底）/DARK
# （暗场）/ FLAT （平场）/OSBS
# （Overscan Bias ）/OSDK （Overscan
# Dark ）/OSFT （Overscan Flat ）/FRNG
# （Fringing），1 种外部定标模式CALI
# （定标天区）和5 种科学目标模式EXDF
# （极深场）/STAR（定标星）/PIPR（PI
# 项目）/TRNS（暂现源观测）/COMB（用
# 于联合观测模式下MCI 的被动曝光）。
# 耗时 19.89462685585022
# {'id': 'as-yqhmztbr12', 'object': 'chat.completion', 'created': 1722395333, 'result': '1. "太赫兹频谱数据包中的DETNAME参数是什么？"\n2. "BEAM_AT参数代表什么？"\n3. "LO_FRQ参数在太赫兹频谱数据包中是什么意思？"\n4. "OBSID中的后端模块是如何表示的？"\n5. "在OBSID中，观测类型的位数是多少？"\n6. "主巡天的观测类型有哪些？"\n7. "CSST_MSC_MS_SCI_xxx.fits文件命名中的SCI代表什么？"\n8. "太赫兹频谱数据包中的FPGA_TEM参数属于哪个分类？"\n9. "在太赫兹观测类型中，OTF扫描模式代表什么？"\n10. "0级数据定义第三版中，obsid的数据结构是如何更改的？"', 'is_truncated': False, 'need_clear_history': False, 'finish_reason': 'normal', 'usage': {'prompt_tokens': 3629, 'completion_tokens': 157, 'total_tokens': 3786}}
# question_text
#  1. "太赫兹频谱数据包中的DETNAME参数是什么？"
# 2. "BEAM_AT参数代表什么？"
# 3. "LO_FRQ参数在太赫兹频谱数据包中是什么意思？"
# 4. "OBSID中的后端模块是如何表示的？"
# 5. "在OBSID中，观测类型的位数是多少？"
# 6. "主巡天的观测类型有哪些？"
# 7. "CSST_MSC_MS_SCI_xxx.fits文件命名中的SCI代表什么？"
# 8. "太赫兹频谱数据包中的FPGA_TEM参数属于哪个分类？"
# 9. "在太赫兹观测类型中，OTF扫描模式代表什么？"
# 10. "0级数据定义第三版中，obsid的数据结构是如何更改的？"
# 耗时 57.90981602668762
# {'id': 'as-g4hqqjhgn7', 'object': 'chat.completion', 'created': 1722395391, 'result': '```json\n[\n    {\n        "content": "太赫兹频谱数据包中的DETNAME参数是什么？",\n        "summary": "DETNAME在太赫兹频谱数据包中表示观测设备选择参数，用于根据配置文件来查询相关的观测参数。"\n    },\n    {\n        "content": "BEAM_AT参数代表什么？",\n        "summary": "BEAM_AT参数代表波束偏离光轴的距离，用CSST本体几何坐标系的x和y方向表征，以及太赫兹焦平面中心处相对于主光轴的方向余弦。"\n    },\n    {\n        "content": "LO_FRQ参数在太赫兹频谱数据包中是什么意思？",\n        "summary": "LO_FRQ参数在太赫兹频谱数据包中表示观测频率参数，包括SIS1和SIS2或SCK观测时LO频率（低字节有效）。"\n    },\n    {\n        "content": "OBSID中的后端模块是如何表示的？",\n        "summary": "OBSID中的后端模块是通过其前3bit来表示的，例如1=主巡天，2=MCI，3=IFS，4=CPIC，5=HSTDM。"\n    },\n    {\n        "content": "在OBSID中，观测类型的位数是多少？",\n        "summary": "在OBSID中，观测类型是通过接下来的5bit来表示的，总共有5位数。"\n    },\n    {\n        "content": "主巡天的观测类型有哪些？",\n        "summary": "主巡天的观测类型包括但不限于SCI（主巡天宽场）、深场观测、9平方度甚深场、银河系核球附近微引力透镜、早期优先观测的弱引力透镜等。"\n    },\n    {\n        "content": "CSST_MSC_MS_SCI_xxx.fits文件命名中的SCI代表什么？",\n        "summary": "在CSST_MSC_MS_SCI_xxx.fits文件命名中，SCI代表科学观测模式，特别是巡天观测。"\n    },\n    {\n        "content": "太赫兹频谱数据包中的FPGA_TEM参数属于哪个分类？",\n        "summary": "FPGA_TEM参数在太赫兹频谱数据包中属于遥测参数及监显要求表，表示频谱主板电压5V。"\n    },\n    {\n        "content": "在太赫兹观测类型中，OTF扫描模式代表什么？",\n        "summary": "在太赫兹观测类型中，OTF扫描模式（OTF）代表一种观测模式，其中望远镜或探测器进行扫描以覆盖更大的天区或实现特定的观测目标。"\n    },\n    {\n        "content": "0级数据定义第三版中，obsid的数据结构是如何更改的？",\n        "summary": "在0级数据定义第三版中，obsid的数据结构进行了更改，将原来用于表示观测类型的4bit增加到了5bit，同时曝光编号的位数从25bit减少到24bit，以适应更多类型的观测需求。"\n    }\n]\n```', 'is_truncated': False, 'need_clear_history': False, 'finish_reason': 'normal', 'usage': {'prompt_tokens': 3860, 'completion_tokens': 647, 'total_tokens': 4507}}
# qa_text
#  ```json
# [
#     {
#         "content": "太赫兹频谱数据包中的DETNAME参数是什么？",
#         "summary": "DETNAME在太赫兹频谱数据包中表示观测设备选择参数，用于根据配置文件来查询相关的观测参数。"
#     },
#     {
#         "content": "BEAM_AT参数代表什么？",
#         "summary": "BEAM_AT参数代表波束偏离光轴的距离，用CSST本体几何坐标系的x和y方向表征，以及太赫兹焦平面中心处相对于主光轴的方向余弦。"
#     },
#     {
#         "content": "LO_FRQ参数在太赫兹频谱数据包中是什么意思？",
#         "summary": "LO_FRQ参数在太赫兹频谱数据包中表示观测频率参数，包括SIS1和SIS2或SCK观测时LO频率（低字节有效）。"
#     },
#     {
#         "content": "OBSID中的后端模块是如何表示的？",
#         "summary": "OBSID中的后端模块是通过其前3bit来表示的，例如1=主巡天，2=MCI，3=IFS，4=CPIC，5=HSTDM。"
#     },
#     {
#         "content": "在OBSID中，观测类型的位数是多少？",
#         "summary": "在OBSID中，观测类型是通过接下来的5bit来表示的，总共有5位数。"
#     },
#     {
#         "content": "主巡天的观测类型有哪些？",
#         "summary": "主巡天的观测类型包括但不限于SCI（主巡天宽场）、深场观测、9平方度甚深场、银河系核球附近微引力透镜、早期优先观测的弱引力透镜等。"
#     },
#     {
#         "content": "CSST_MSC_MS_SCI_xxx.fits文件命名中的SCI代表什么？",
#         "summary": "在CSST_MSC_MS_SCI_xxx.fits文件命名中，SCI代表科学观测模式，特别是巡天观测。"
#     },
#     {
#         "content": "太赫兹频谱数据包中的FPGA_TEM参数属于哪个分类？",
#         "summary": "FPGA_TEM参数在太赫兹频谱数据包中属于遥测参数及监显要求表，表示频谱主板电压5V。"
#     },
#     {
#         "content": "在太赫兹观测类型中，OTF扫描模式代表什么？",
#         "summary": "在太赫兹观测类型中，OTF扫描模式（OTF）代表一种观测模式，其中望远镜或探测器进行扫描以覆盖更大的天区或实现特定的观测目标。"
#     },
#     {
#         "content": "0级数据定义第三版中，obsid的数据结构是如何更改的？",
#         "summary": "在0级数据定义第三版中，obsid的数据结构进行了更改，将原来用于表示观测类型的4bit增加到了5bit，同时曝光编号的位数从25bit减少到24bit，以适应更多类型的观测需求。"
#     }
# ]
# ```
# File 'new_file.txt' has been created and written.
# new_txt_files/text_file13.txt
# text_content
#  第5.2.2 章，TYPE 描述：TYPE 表示目标
# 类型，共有9 种类型，包括3 种内部定
# 标模式BIAS（本底）/DARK（暗场）/
# FLAT（平场），2 种外部定标模式CALS
# （定标星）/CALF（定标天区）和4 种科
# 学目标模式EXDF（极深场）/PI（PI 项
# 目）/TRNS（暂现源观测）/COMB（用于
# 联合观测模式下MCI 的被动曝光）。
# 第5.2.2 章，文件名举例如下：
# CSST_MCI_C1_STAR_20240101120000_2
# 0240101120230_20500000012_01_L0_V01.
# fits
# 第5.2.2 章，文件名举例如下：
# CSST_MCI_C1_CALS_20240101120000_2
# 0240101120230_21000000012_01_L0_V01.
# fits
# 第5.2.2 章，示例文件名（包括路径）：
# CSST_L0/MCI/SCI/60310/200000012/CSS
# T_MCI_C1_STAR_20240101120000_2024
# 0101120230_20500000012_01_L0_V01.fits
# 第5.2.2 章，示例文件名（包括路径）：
# CSST_L0/MCI/SCI/60310/21000000012/CS
# ST_MCI_C1_CALS_20240101120000_202
# 40101120230_21000000012_01_L0_V01.fit
# s
# 第5.2.2 章，图2，ExpID
# 第5.2.2 章，图2，OBSID
# 第5.3.2 章，图10 注释：每个通道输出各
# 自物理区域（如上图）共计1499×4936
# （pixels）...一帧0 级数据image data 输出
# 像元尺寸：23984×4936（pixels）
# 第5.3.2 章，图10 注释：每个通道输出各
# 自物理区域（如上图）共计1499（列）
# ×4936（行）（pixels）...一帧0 级数据
# image data 输出像元尺寸：23984（列）
# 120
# ×4936（行）（pixels）
# 第5.4.2 章，表3 中的全局关键字从
# DATE 到EXPTIME，都复制了一份到表6
# 第5.4.2 章，表6，删除关键字MCITEMP
# 第5.4.2 章，表6 ，增加关键字
# CHANNEL，FLITERNO，DETTEMP0，
# DETTEMP1，DETTEMP3，GAINLVL
# 第5.3.2 章，image data 说明：以探测器选
# 型使用CCD 为例，如果按照计划的16 通
# 道读出，需要将16 通道数据按照读出先
# 后次序，顺序排列为一个2 维矩阵
# 第5.3.2 章，image data 说明：以探测器选
# 型使用CCD 为例，需要按照通道号从小
# 到大的顺序将16 通道数据从左到右排列
# 为一个二维矩阵
# 第5.4.2 章，表6，关键字NCHAN
# 第5.4.2 章，表6，关键字NCHANNAL
# 第5.4.2 章，表6，删除关键字others
# 第5.4.2 章，表6，删除关键字READT0,
# READT1
# IFS
# 第5.2.3 章，TYPE 描述：TYPE 为目标类
# 型，4 位字符串，有5 种类型...2 种科学
# 目标模式SCIE（IFS 为主要观测设备时的
# 科学观测目标）/COMB（IFS 为辅助观测
# 设备时的观测目标）。
# 第5.2.3 章，TYPE 描述：TYPE 为目标类
# 型，共有5 种类型...2 种科学目标模式
# SCI（IFS 为主要观测设备时的科学观测目
# 标）/COMB（IFS 为辅助观测设备时的观
# 测目标）。
# 第5.2.3 章，文件名描述：hhmmss 是六位
# 数UTC 观测时间，说明同上。
# 第5.2.3 章，文件名描述：hhmmss 是六位
# 数UTC 观测时间，说明同上。一个obsid
# 的观测中，如果涉及多帧观测，则第一个
# hhmmss 为第一帧数据开始观测时间，第
# 二个hhmmss 定义为最后一帧数据的观测
# 121
# 结束时间。
# 第5.2.3 章，文件名举例如下：
# CSST_IFS_R_SCIE_20240101120000_202
# 40101120230_30100000012_R_L0_V01.fits
# 第5.2.3 章，文件名举例如下：
# CSST_IFS_R_SCI_20240101120000_20240
# 101120230_30100000012_R_L0_V01.fits
# 第5.2.3 章，示例文件名（包括路径）：
# CSST_L0/IFS/SCI/60310/CSST_IFS_R_SC
# IE_20240101120000_20240101120230_301
# 00000012_R_L0_V01.fits
# 第5.2.3 章，示例文件名（包括路径）：
# CSST_L0/IFS/SCI/60310/CSST_IFS_R_SCI
# _20240101120000_20240101120230_30100
# 000012_R_L0_V01.fits
# 第5.2.3 章，HDU 描述：IFS 的image
# data 数据应该为一个2 维的datacube 矩
# 阵，以探测器选型使用CCD 为例，如果
# 按照计划的4 通道读出，需要将4 通道数
# 据按照读出先后次序，顺序排列为一个2
# 维矩阵（如图12 所示）。
# 第5.2.3 章，HDU 描述：IFS 的image data
# 数据应该为一个3 维的datacube 矩阵，以
# 探测器选型使用CCD 为例，如果按照计
# 划的4 通道读出，需要将4 通道数据按照
# 读出先后次序，顺序排列为一个2 维矩阵,
# 在此2 维矩阵的基础上，第三维为在相同
# 曝光、指向、跟踪、obsid 下，一次采集
# 的帧数n（如图12 所示）。
# 第5.2.3 章，图12
# 第5.2.3 章，图12 更新
# 第5.2.3 章，图12 注释：其中数字表示不
# 同的读出通道，通道间的分隔用黑色边框
# 表示。橙色为data 区域，蓝色为over
# (pre) scan 区域，（0，0）在左上角。
# 第5.2.3 章，图12 注释：其中数字表示不
# 同的读出通道，通道间的分隔用黑色边框
# 表示。橙色为data 区域，蓝色为over
# (pre) scan 区域，（0，0）在左上角。1, 2,
# 3, 4 表示同一个探测器不同的读出通道
# （门）。共有4 个输出通道, 每个通道都
# 含有50 列prescan, 320 行及320 列
# overscan。其中，蓝端探测器CCD 每个读
# 出通道（门）的物理区域如上图所示，
# 1344（行）*2418（列）（pixels），一帧
# 紫外图像数据，需要传输1344 次。其
# 122
# 中，1344=1024 （physical pixels ）+320
# （virtual overscan）；2418=50（prescan）
# +2048 （physical pixels ）+320 （virtual
# overscan）；一帧0 级数据image data 输
# 出像元尺寸：1344（行）×9672（列）
# （pixels）。红端探测器CCD 每个读出通
# 道（门）的物理区域如上图所示，1856
# （行）* 3442（列）（pixels），一帧可见
# 光图像数据，需要传输1856 次。其中，
# 1856=1536（physical pixels）+320（virtual
# overscan ）；3442=50 （prescan ）+3072
# （physical
# pixels ）+320 （virtual
# overscan）；一帧0 级数据image data 输
# 出像元尺寸：1856（行）×13768（列）
# （pixels）。
# 第5.4.2 章，表7，增加关键字NAXIS3,
# PCOUNT, GCOUNT, EXPT0_1, EXPT1_1,
# EXPT0_2, EXPT1_2, EXPT0_3, EXPT1_3,
# DARK1, DARK2, DARK3, DARK4
# 第5.4.2 章，表7，删除关键字READT0,
# READT1
# CPIC
# 第5.2.4 章，TYPE 描述：TYPE 表示目标
# 类型，4 位字符串，共8 种类型，包括5
# 种定标模式BIAS（本底）/DARK（暗
# 场）/ FLAT（平场）/BKGD（天空背景定
# 第5.2.4 章，TYPE 描述：TYPE 表示目标
# 类型，共有8 种类型，包括5 种定标模
# 式BIAS（本底）/DARK（暗场）/ FLAT
# （平场）/BKG（天空背景定标）/LASER
# 123
# 标）/LASR（内部激光器定标）和3 种科
# 学目标模式SCIE （科学观测）/DENF
# （密集星场观测）/CALS （定标星观
# 测）。
# （内部激光器定标）和3 种科学目标模式
# SCI（科学观测）/DSF（密集星场观测）
# /CALS（定标星观测）。
# 第5.2.4 章，文件名举例如下：
# CSST_CPIC_VIS_SCIE_20240101120000_
# 20240101120230_40100000012_X_L0_V01
# .fits
# 第5.2.4 章，文件名举例如下：
# CSST_CPIC_VIS_SCI_20240101120000_2
# 0240101120230_40100000012_X_L0_V01.f
# its
# 第5.2.4 章，示例文件名（包括路径）：
# CSST_L0/CPIC/SCI/60310/VIS/CSST_CPI
# C_VIS_SCIE_20240101120000_202401011
# 20230_40100000012_X_L0_V01.fits
# 第5.2.4 章，示例文件名（包括路径）：
# CSST_L0/CPIC/SCI/60310/VIS/CSST_CPI
# C_VIS_SCI_20240101120000_2024010112
# 0230_40100000012_X_L0_V01.fits
# 第5.4.2 章，表8，删除关键字others
# HSTDM
# 第5.2.5 章，TYPE 描述：地面发出一次观
# 测指令（对应一个OBSID），每个探测器
# 的读出数据包含两部分：对目标源进行观
# 测时，产生目标源的观测数据
# （ONS_SCI ）和黑体校准数据
# （ONS_BLK）
# 第5.2.5 章，TYPE 描述：地面发出一次
# 观测指令（对应一个OBSID），每个探
# 测器的读出数据包含4 个类型:对目标源
# 进行观测时，产生目标源的观测数据
# （ON_SCI ）和黑体校准数据
# （ON_BLK）
# 第5.4.2 章，表9，增加关键字NAXIS2，
# NAXIS3 ，PCOUNT ，GCOUNT ，
# BEAM_AT1
# ，
# BEAM_AT2
# ，
# BEAM_AT3，BEAM_AT4，BEAM_AT5
# 第5.4.2 章，表9 ，删除关键字
# DEW_8K ，FPGA_TEM ，FFT_5V ，
# 124
# FFT_3V
# 耗时 16.815489530563354
# {'id': 'as-r8k5wy3tba', 'object': 'chat.completion', 'created': 1722395408, 'result': '1. MCI数据中的TYPE有几种类型？\n2. IFS数据文件名中TYPE字段的长度是多少？\n3. CSST_MCI_C1_STAR文件名中的20240101120000代表什么？\n4. IFS图像数据的维度是多少？\n5. CPIC数据的TYPE字段有几种类型？\n6. HSTDM观测指令对应的数据包含哪两部分？\n7. CSST_IFS_R_SCIE文件名中的30100000012是什么？\n8. CSST_CPIC_VIS_SCIE文件名中VIS表示什么？\n9. IFS的image data数据为什么要按照读出通道顺序排列？\n10. 表6和表7中，被删除的关键字有哪些是共同的？', 'is_truncated': False, 'need_clear_history': False, 'finish_reason': 'normal', 'usage': {'prompt_tokens': 3227, 'completion_tokens': 165, 'total_tokens': 3392}}
# question_text
#  1. MCI数据中的TYPE有几种类型？
# 2. IFS数据文件名中TYPE字段的长度是多少？
# 3. CSST_MCI_C1_STAR文件名中的20240101120000代表什么？
# 4. IFS图像数据的维度是多少？
# 5. CPIC数据的TYPE字段有几种类型？
# 6. HSTDM观测指令对应的数据包含哪两部分？
# 7. CSST_IFS_R_SCIE文件名中的30100000012是什么？
# 8. CSST_CPIC_VIS_SCIE文件名中VIS表示什么？
# 9. IFS的image data数据为什么要按照读出通道顺序排列？
# 10. 表6和表7中，被删除的关键字有哪些是共同的？
# 耗时 67.70460867881775
# {'id': 'as-bhyu3c05e4', 'object': 'chat.completion', 'created': 1722395476, 'result': '```json\n[\n    {\n        "content": "MCI数据中的TYPE有几种类型？",\n        "summary": "MCI数据中的TYPE共有9种类型，包括3种内部定标模式（BIAS/DARK/FLAT），2种外部定标模式（CALS/CALF）和4种科学目标模式（EXDF/PI/TRNS/COMB）。"\n    },\n    {\n        "content": "IFS数据文件名中TYPE字段的长度是多少？",\n        "summary": "IFS数据文件名中TYPE字段的长度是4位字符串。"\n    },\n    {\n        "content": "CSST_MCI_C1_STAR文件名中的20240101120000代表什么？",\n        "summary": "CSST_MCI_C1_STAR文件名中的20240101120000代表UTC观测时间，格式为年月日时分秒（2024年01月01日12时00分00秒）。"\n    },\n    {\n        "content": "IFS图像数据的维度是多少？",\n        "summary": "IFS图像数据的维度依赖于探测器的读出通道数量和观测的帧数。对于使用CCD探测器的IFS数据，如果计划使用4通道读出，则image data数据应该为一个三维datacube矩阵，其中前两个维度为图像尺寸（例如1344行×9672列或1856行×13768列），第三维为帧数n。"\n    },\n    {\n        "content": "CPIC数据的TYPE字段有几种类型？",\n        "summary": "CPIC数据的TYPE字段共有8种类型，包括5种定标模式（BIAS/DARK/FLAT/BKGD/LASER）和3种科学目标模式（SCIE/DENF/CALS）。"\n    },\n    {\n        "content": "HSTDM观测指令对应的数据包含哪两部分？",\n        "summary": "HSTDM观测指令对应的数据包含两部分：对目标源进行观测时产生的目标源观测数据（ONS_SCI或ON_SCI）和黑体校准数据（ONS_BLK或ON_BLK）。"\n    },\n    {\n        "content": "CSST_IFS_R_SCIE文件名中的30100000012是什么？",\n        "summary": "CSST_IFS_R_SCIE文件名中的30100000012可能是代表某种编号或序列号，具体含义可能需要根据上下文或相关文档来确定。"\n    },\n    {\n        "content": "CSST_CPIC_VIS_SCIE文件名中VIS表示什么？",\n        "summary": "CSST_CPIC_VIS_SCIE文件名中的VIS表示CPIC数据的可见光波段（Visible）部分。"\n    },\n    {\n        "content": "IFS的image data数据为什么要按照读出通道顺序排列？",\n        "summary": "IFS的image data数据按照读出通道顺序排列是为了保持数据的连续性和便于后续处理。如果探测器使用多通道读出，将不同通道的数据按照读出顺序排列可以形成一个有序的二维矩阵，从而方便进行图像重建和数据分析。"\n    },\n    {\n        "content": "表6和表7中，被删除的关键字有哪些是共同的？",\n        "summary": "在表6和表7中，共同被删除的关键字包括READT0和READT1。"\n    }\n]\n```', 'is_truncated': False, 'need_clear_history': False, 'finish_reason': 'normal', 'usage': {'prompt_tokens': 3466, 'completion_tokens': 758, 'total_tokens': 4224}}
# qa_text
#  ```json
# [
#     {
#         "content": "MCI数据中的TYPE有几种类型？",
#         "summary": "MCI数据中的TYPE共有9种类型，包括3种内部定标模式（BIAS/DARK/FLAT），2种外部定标模式（CALS/CALF）和4种科学目标模式（EXDF/PI/TRNS/COMB）。"
#     },
#     {
#         "content": "IFS数据文件名中TYPE字段的长度是多少？",
#         "summary": "IFS数据文件名中TYPE字段的长度是4位字符串。"
#     },
#     {
#         "content": "CSST_MCI_C1_STAR文件名中的20240101120000代表什么？",
#         "summary": "CSST_MCI_C1_STAR文件名中的20240101120000代表UTC观测时间，格式为年月日时分秒（2024年01月01日12时00分00秒）。"
#     },
#     {
#         "content": "IFS图像数据的维度是多少？",
#         "summary": "IFS图像数据的维度依赖于探测器的读出通道数量和观测的帧数。对于使用CCD探测器的IFS数据，如果计划使用4通道读出，则image data数据应该为一个三维datacube矩阵，其中前两个维度为图像尺寸（例如1344行×9672列或1856行×13768列），第三维为帧数n。"
#     },
#     {
#         "content": "CPIC数据的TYPE字段有几种类型？",
#         "summary": "CPIC数据的TYPE字段共有8种类型，包括5种定标模式（BIAS/DARK/FLAT/BKGD/LASER）和3种科学目标模式（SCIE/DENF/CALS）。"
#     },
#     {
#         "content": "HSTDM观测指令对应的数据包含哪两部分？",
#         "summary": "HSTDM观测指令对应的数据包含两部分：对目标源进行观测时产生的目标源观测数据（ONS_SCI或ON_SCI）和黑体校准数据（ONS_BLK或ON_BLK）。"
#     },
#     {
#         "content": "CSST_IFS_R_SCIE文件名中的30100000012是什么？",
#         "summary": "CSST_IFS_R_SCIE文件名中的30100000012可能是代表某种编号或序列号，具体含义可能需要根据上下文或相关文档来确定。"
#     },
#     {
#         "content": "CSST_CPIC_VIS_SCIE文件名中VIS表示什么？",
#         "summary": "CSST_CPIC_VIS_SCIE文件名中的VIS表示CPIC数据的可见光波段（Visible）部分。"
#     },
#     {
#         "content": "IFS的image data数据为什么要按照读出通道顺序排列？",
#         "summary": "IFS的image data数据按照读出通道顺序排列是为了保持数据的连续性和便于后续处理。如果探测器使用多通道读出，将不同通道的数据按照读出顺序排列可以形成一个有序的二维矩阵，从而方便进行图像重建和数据分析。"
#     },
#     {
#         "content": "表6和表7中，被删除的关键字有哪些是共同的？",
#         "summary": "在表6和表7中，共同被删除的关键字包括READT0和READT1。"
#     }
# ]
# ```
# File 'new_file.txt' has been created and written.

# %% [markdown]
# ## 将问答对保存到df中

# %%
import pandas as pd
import json
import glob

def clean_json_content(content):
    # 去掉开头的 'json\n[' 和结尾的 ']'
    if content.startswith("```json\n["):
        content = content[9:].strip()  # 去掉 'json\n['
    if content.endswith(']\n```'):
        content = content[:-6].strip()  # 去掉 ']'

    # 确保去掉多余的 [ 和 ]
    if content.startswith("["):
        content = content[1:].strip()
    if content.endswith("]"):
        content = content[:-1].strip()

    # 检查内容的结尾是否是完整的 {"content": ,"summary": } 对
    while content:
        try:
            json.loads(f"[{content}]")
            break  # 如果内容是完整的 JSON，则不需要删除
        except json.JSONDecodeError:
            # 如果内容不是完整的 JSON，则删除最后一个字符并继续检查
            content = content.rsplit(',', 1)[0].strip()
            continue

    return content

# 获取所有以 new_file_ 开头的 .txt 文件
file_list = glob.glob("generated_txt_files/new_file_*.txt")

# 初始化一个空列表来存储所有的 JSON 对象
json_objects = []

# 遍历每个文件并将内容合并到 json_objects 列表中
for file_name in file_list:
    try:
        with open(file_name, "r", encoding="utf-8") as file:
            content = file.read().strip()
            cleaned_content = clean_json_content(content)  # 这里可能会抛出异常

        # 将处理后的内容解析为 JSON 对象并添加到 json_objects 列表中
        try:
            json_objects.extend(json.loads(f"[{cleaned_content}]"))
            print(file_name)
        except json.JSONDecodeError as e:
            print(f"Error decoding JSON in file {file_name}: {e}")
            print(f"Content: {cleaned_content}")

    except Exception as e:  # 捕获 clean_json_content() 函数的异常
        print(f"Error processing file {file_name}: {e}")
        continue  # 跳过当前循环，继续执行下一个循环
    
# 转换为 DataFrame
df1 = pd.DataFrame(json_objects)

# 确保 DataFrame 只有 "content" 和 "summary" 两列
df1 = df1[['content', 'summary']]

# 检查 DataFrame 内容
print(df1)
# Out:
# generated_txt_files/new_file_20240731025743.txt
# generated_txt_files/new_file_20240731025608.txt
# generated_txt_files/new_file_20240731030524.txt
# generated_txt_files/new_file_20240731030311.txt
# generated_txt_files/new_file_20240731025912.txt
# generated_txt_files/new_file_20240731030203.txt
# generated_txt_files/new_file_20240731031116.txt
# generated_txt_files/new_file_20240731030643.txt
# generated_txt_files/new_file_20240731030415.txt
# generated_txt_files/new_file_20240731025433.txt
# generated_txt_files/new_file_20240731030951.txt
# generated_txt_files/new_file_20240731030833.txt
# generated_txt_files/new_file_20240731030042.txt
#                                content  \
# 0               主巡天模块0级数据的文件夹命名结构是怎样的？
# 1         MCI模块中，每个探测器单次曝光的数据存储在什么文件中？
# 2         IFS模块的0级数据文件名中，CAMERA字段代表什么？
# 3    CPIC模块的可见光相机和红外相机在0级数据文件名中分别如何表示？
# 4        HSTDM模块中，探测器的黑体校准数据在文件名中如何标识？
# ..                                 ...
# 125       对于MSC_IR，DETSIZE表示什么，其数据类型是？
# 126    MCI数据文件头中的IMGNUM是什么意思，其数据类型是什么？
# 127       MCI的FILTERNO指的是什么，其数据类型是怎样的？
# 128     CSST_MCI数据文件头中的DATE代表什么，数据类型是？
# 129      对于MCI数据文件，OBSID的含义是什么，其数据类型是？
#
#                                                summary
# 0    主巡天模块0级数据的文件夹命名结构从设备总体到不同终端的不同功能层层递进，例如：CSST_L...
# 1    MCI模块中，每个探测器单次曝光（含BIAS读取等定标过程）的读出数据存储为一个FITS文件...
# 2    IFS模块的0级数据文件名中，CAMERA字段代表光谱仪编号，红端CCD为“R”，蓝端CCD...
# 3          CPIC模块的0级数据文件名中，可见光相机和红外相机分别用“VIS”和“NIR”表示。
# 4    HSTDM模块中，探测器的黑体校准数据在文件名中通过TYPE2字段标识为“BLK”，如CSS...
# ..                                                 ...
# 125  对于MSC_IR，DETSIZE表示探测器的大小，通常以像素为单位（例如'640x512'）...
# 126  MCI数据文件头中的IMGNUM表示图像编号，是整数型（int），用于区分同一观测序列中的不...
# 127  MCI的FILTERNO指的是使用的滤光片编号，是字符串型（str），用于标识观测时所使用的...
# 128  CSST_MCI数据文件头中的DATE代表文件写入的日期和时间（yyyy-mm-ddThh:...
# 129     对于MCI数据文件，OBSID的含义是观测ID，是字符串型（str），用于唯一标识一次观测。
#
# [130 rows x 2 columns]

# %%
df1
# Out:
#                                content  \
# 0               主巡天模块0级数据的文件夹命名结构是怎样的？
# 1         MCI模块中，每个探测器单次曝光的数据存储在什么文件中？
# 2         IFS模块的0级数据文件名中，CAMERA字段代表什么？
# 3    CPIC模块的可见光相机和红外相机在0级数据文件名中分别如何表示？
# 4        HSTDM模块中，探测器的黑体校准数据在文件名中如何标识？
# ..                                 ...
# 125       对于MSC_IR，DETSIZE表示什么，其数据类型是？
# 126    MCI数据文件头中的IMGNUM是什么意思，其数据类型是什么？
# 127       MCI的FILTERNO指的是什么，其数据类型是怎样的？
# 128     CSST_MCI数据文件头中的DATE代表什么，数据类型是？
# 129      对于MCI数据文件，OBSID的含义是什么，其数据类型是？
#
#                                                summary
# 0    主巡天模块0级数据的文件夹命名结构从设备总体到不同终端的不同功能层层递进，例如：CSST_L...
# 1    MCI模块中，每个探测器单次曝光（含BIAS读取等定标过程）的读出数据存储为一个FITS文件...
# 2    IFS模块的0级数据文件名中，CAMERA字段代表光谱仪编号，红端CCD为“R”，蓝端CCD...
# 3          CPIC模块的0级数据文件名中，可见光相机和红外相机分别用“VIS”和“NIR”表示。
# 4    HSTDM模块中，探测器的黑体校准数据在文件名中通过TYPE2字段标识为“BLK”，如CSS...
# ..                                                 ...
# 125  对于MSC_IR，DETSIZE表示探测器的大小，通常以像素为单位（例如'640x512'）...
# 126  MCI数据文件头中的IMGNUM表示图像编号，是整数型（int），用于区分同一观测序列中的不...
# 127  MCI的FILTERNO指的是使用的滤光片编号，是字符串型（str），用于标识观测时所使用的...
# 128  CSST_MCI数据文件头中的DATE代表文件写入的日期和时间（yyyy-mm-ddThh:...
# 129     对于MCI数据文件，OBSID的含义是观测ID，是字符串型（str），用于唯一标识一次观测。
#
# [130 rows x 2 columns]

# %%
df1.to_csv("QA_新0级数据.csv")
